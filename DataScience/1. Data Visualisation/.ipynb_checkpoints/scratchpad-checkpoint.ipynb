# %%
import pandas as pd
houses = pd.read_csv("data/kc_house_data.csv")
titanic = pd.read_csv("data/titanic.csv")
netflix = pd.read_csv("data/netflix_titles.csv", sep="|", index_col=0)
btc = pd.read_csv("data/coin_Bitcoin.csv")
countries = pd.read_csv("data/world-happiness-report-2021.csv")

# %%
btc.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
btc.drop(["SNo", "Name"], axis=1)
# Out:
#      Symbol                 Date          High           Low          Open  \
# 0       BTC  2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1       BTC  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2       BTC  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3       BTC  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4       BTC  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...     ...                  ...           ...           ...           ...
# 2986    BTC  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987    BTC  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988    BTC  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989    BTC  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990    BTC  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %%
btc.drop(columns=["SNo", "Name"])
# Out:
#      Symbol                 Date          High           Low          Open  \
# 0       BTC  2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1       BTC  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2       BTC  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3       BTC  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4       BTC  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...     ...                  ...           ...           ...           ...
# 2986    BTC  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987    BTC  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988    BTC  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989    BTC  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990    BTC  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %%
btc.drop([0,2,4], axis=0)
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 5        6  Bitcoin    BTC  2013-05-04 23:59:59    115.000000     92.500000
# 6        7  Bitcoin    BTC  2013-05-05 23:59:59    118.800003    107.142998
# 7        8  Bitcoin    BTC  2013-05-06 23:59:59    124.663002    106.639999
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
countries.set_index("Country name", inplace=True)

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(["Iceland"])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(["Finland", "Denmark", "Iceland"], inplace=True)

# %%
countries.drop(index=["Norway"])
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Switzerland          Western Europe         7.571
# Netherlands          Western Europe         7.464
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# ...                             ...           ...
# Lesotho          Sub-Saharan Africa         3.512
# Botswana         Sub-Saharan Africa         3.467
# Rwanda           Sub-Saharan Africa         3.415
# Zimbabwe         Sub-Saharan Africa         3.145
# Afghanistan              South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Netherlands                            0.027         7.518         7.410
# Sweden                                 0.036         7.433         7.293
# ...

# %%
houses["price_sqft"] = houses["price"]/houses["sqft_living"]
houses.sort_values("price_sqft", ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 19336  6021500970  20150407T000000   874950.0         2       1.00
# 4013    724069059  20140509T000000  2400000.0         3       2.25
# 10446  1118000320  20150508T000000  3400000.0         4       4.00
# 8623   6303400395  20150130T000000   325000.0         1       0.75
# 9314   4389200610  20141201T000000   903000.0         2       1.50
# ...           ...              ...        ...       ...        ...
# 1385   3342700465  20150123T000000   250000.0         3       1.50
# 17197  5111400086  20140512T000000   110000.0         3       1.00
# 13825  5637200450  20141017T000000   257000.0         5       2.75
# 3785    723049156  20140523T000000   149000.0         3       1.00
# 18262  2891000610  20141211T000000   148900.0         4       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 19336         1080      4000     1.0           0     0  ...        1080
# ...

# %%
# titanic.age.replace("?", [None])
# titanic.age.astype("float")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-3b0b379c7f54> in <module>
# ----> 1 titanic.age.replace("?", [None])
#       2 # titanic.age.astype("float")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4507         method="pad",
#    4508     ):
# -> 4509         return super().replace(
#    4510             to_replace=to_replace,
#    4511             value=value,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6933                     )
#    6934                 else:
# -> 6935                     raise TypeError(
#    6936                         f'Invalid "to_replace" type: {repr(type(to_replace).__name__)}'
#    6937                     )
#
# ...

# %%
titanic.age.replace(["?"], [None], inplace=True)

# %%
titanic.age.astype("float64")
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-163-2022c9970b91> in <module>
# ----> 1 countries.loc[["Denmark", "Iceland", "Finland", "Sweden", "Norway"]]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# ...

# %%
countries.loc[["Sweden", "Norway"], ["Grouping", "isCold"]] = ["Nordic", "YES!"]

# %%
countries.loc[["Sweden", "Norway"]]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Sweden           Western Europe         7.363                           0.036
# Norway           Western Europe         7.392                           0.035
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Sweden               7.433         7.293                 10.867
# Norway               7.462         7.323                 11.053
#
#               Social support  Healthy life expectancy  \
# Country name
# Sweden                 0.934                     72.7
# Norway                 0.954                     73.3
#
#               Freedom to make life choices  Generosity  ...  \
# Country name                                            ...
# Sweden                               0.945       0.086  ...
# Norway                               0.960       0.093  ...
#
#               Ladder score in Dystopia  Explained by: Log GDP per capita  \
# ...

# %%
countries.iloc[0:5] = 'PIG'

# %%
countries
# Out:
#               Regional indicator Ladder score Standard error of ladder score  \
# Country name
# Switzerland                  PIG          PIG                            PIG
# Netherlands                  PIG          PIG                            PIG
# Norway                       PIG          PIG                            PIG
# Sweden                       PIG          PIG                            PIG
# Luxembourg                   PIG          PIG                            PIG
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic.age = titanic.age.astype("float")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
stats = pd.read_csv("data/game_stats.csv")

# %%
stats.fillna({"league": "amateur","points": 0, "assists": 0, "rebounds": 0})
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie     amateur    10.0      0.0       2.0
# 2       stu  euroleague     0.0      0.0       0.0
# 3   jackson         aba     9.0      0.0       2.0
# 4  timothee     amateur     8.0      0.0       0.0
# 5     steph         nba    49.0      8.0      10.0

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       6 non-null      object
#  1   league     4 non-null      object
#  2   points     5 non-null      float64
#  3    assists   2 non-null      float64
#  4    rebounds  4 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 368.0+ bytes

# %%
sales = pd.read_csv("data/sales.csv")

# %%
sales.dropna(how="all")
# Out:
#    rating  shipping_zip  billing_zip
# 0     5.0           NaN      81220.0
# 1     4.5       94931.0      94931.0
# 2     NaN       92625.0      92625.0
# 3     4.5       10003.0      10003.0
# 4     4.0           NaN      92660.0
# 6     NaN       60007.0      60007.0

# %%
sales.dropna(subset=["rating"])
# Out:
#    rating  shipping_zip  billing_zip
# 0     5.0           NaN      81220.0
# 1     4.5       94931.0      94931.0
# 3     4.5       10003.0      10003.0
# 4     4.0           NaN      92660.0

# %%
sales
# Out:
#    rating  shipping_zip  billing_zip
# 0     5.0           NaN      81220.0
# 1     4.5       94931.0      94931.0
# 2     NaN       92625.0      92625.0
# 3     4.5       10003.0      10003.0
# 4     4.0           NaN      92660.0
# 5     NaN           NaN          NaN
# 6     NaN       60007.0      60007.0

# %%
sales["shipping_zip"].fillna(sales["billing_zip"])

# %%
df = pd.read_csv("data/pollution.csv")

# %%
df["date"] = pd.to_datetime(df["Measurement date"])

# %%
weekends = (df["date"].dt.weekday == 5) | (df["date"].dt.weekday == 6)
weekdays = ~weekends
df[weekends]

# %%
df[weekdays]['NO2'].mean()
