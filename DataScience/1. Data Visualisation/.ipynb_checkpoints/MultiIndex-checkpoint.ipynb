# %%
import pandas as pd

# %%
pops = pd.read_csv("data/state_pops.csv")

# %%
pops.set_index(["state", "year"], inplace=True)

# %%
pops.index
# Out:
# MultiIndex([( 'AL', 2012),
#             ( 'AL', 2010),
#             ( 'AL', 2011),
#             ( 'AL', 2009),
#             ( 'AL', 2013),
#             ( 'AL', 2007),
#             ( 'AL', 2008),
#             ( 'AL', 2005),
#             ( 'AL', 2006),
#             ( 'AL', 2004),
#             ...
#             ('USA', 2004),
#             ('USA', 2005),
#             ('USA', 2006),
#             ('USA', 2007),
#             ('USA', 2008),
#             ('USA', 2013),
#             ('USA', 2009),
#             ('USA', 2010),
#             ('USA', 2011),
#             ('USA', 2012)],
#            names=['state', 'year'], length=1272)

# %%
pops.sort_index()
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.loc["CO"]
# Out:
#       population
# year
# 1990   3307618.0
# 1992   3495939.0
# 1991   3387119.0
# 1994   3724168.0
# 1993   3613734.0
# 1995   3826653.0
# 1996   3919972.0
# 1997   4018293.0
# 1998   4116639.0
# 2000   4326921.0
# 1999   4226018.0
# 2002   4490406.0
# 2001   4425687.0
# 2004   4575013.0
# 2003   4528732.0
# 2006   4720423.0
# 2005   4631888.0
# 2008   4889730.0
# 2007   4803868.0
# 2009   4972195.0
# 2013   5268367.0
# 2010   5048196.0
# 2011   5118400.0
# 2012   5189458.0

# %%
pops.loc[["CO", "CA"]]
# Out:
#             population
# state year
# CO    1990   3307618.0
#       1992   3495939.0
#       1991   3387119.0
#       1994   3724168.0
#       1993   3613734.0
#       1995   3826653.0
#       1996   3919972.0
#       1997   4018293.0
#       1998   4116639.0
#       2000   4326921.0
#       1999   4226018.0
#       2002   4490406.0
#       2001   4425687.0
#       2004   4575013.0
#       2003   4528732.0
#       2006   4720423.0
#       2005   4631888.0
#       2008   4889730.0
#       2007   4803868.0
#       2009   4972195.0
#       2013   5268367.0
#       2010   5048196.0
#       2011   5118400.0
#       2012   5189458.0
# CA    2012  37999878.0
#       2011  37668681.0
#       2010  37333601.0
#       2013  38332521.0
#       2009  36961229.0
#       2007  36250311.0
#       2008  36604337.0
#       2005  35827943.0
#       2006  36021202.0
#       2003  35253159.0
#       2004  35574576.0
#       2001  34479458.0
#       2002  34871843.0
#       1999  33499204.0
# ...

# %%
pops.sort_index().loc["NV": "OK"]
# Out:
#             population
# state year
# NV    1990   1220695.0
#       1991   1296172.0
#       1992   1351367.0
#       1993   1411215.0
#       1994   1499298.0
# ...                ...
# OK    2009   3717572.0
#       2010   3759263.0
#       2011   3785534.0
#       2012   3815780.0
#       2013   3850568.0
#
# [96 rows x 1 columns]

# %%
pops.loc[("CA", 2000)]
# Out:
# population    33987977.0
# Name: (CA, 2000), dtype: float64

# %%
pops.loc[:, "population"]
# Out:
# state  year
# AL     2012      4817528.0
#        2010      4785570.0
#        2011      4801627.0
#        2009      4757938.0
#        2013      4833722.0
#                   ...
# USA    2013    316128839.0
#        2009    306771529.0
#        2010    309326295.0
#        2011    311582564.0
#        2012    313873685.0
# Name: population, Length: 1272, dtype: float64

# %%
pops.loc[(["CA", "NV"], 2000)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2000
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-be49e69d4a64> in <module>
# ...

# %%
pops.sort_index(inplace=True)

# %%
pops.loc[(["CA", "CO"], 1990), "population"]
# Out:
# state  year
# CA     1990    29959515.0
# CO     1990     3307618.0
# Name: population, dtype: float64

# %%
pops.loc[(["CA", "CO"], 1990), :]
# Out:
#             population
# state year
# CA    1990  29959515.0
# CO    1990   3307618.0

# %%
pops.loc[("CA", 1990): ("AK", 1999)]
# Out:
# Empty DataFrame
# Columns: [population]
# Index: []

# %%
pops.loc[("CA", [1990,2005]), "population"]
# Out:
# state  year
# CA     1990    29959515.0
#        2005    35827943.0
# Name: population, dtype: float64

# %%
#THIS DONT WORK!!
pops.loc[(:, [1990,2005]), :]
# Out:
#   File "<ipython-input-37-28c02d14b07d>", line 1
#     pops.loc[(:, [1990,2005]), :]
#               ^
# SyntaxError: invalid syntax

# %%
pops.loc[(slice(None), [1990,2005]), :]
# Out:
#             population
# state year
# AK    1990    553290.0
#       2005    666946.0
# AL    1990   4050055.0
#       2005   4569805.0
# AR    1990   2356586.0
# ...                ...
# WI    2005   5546166.0
# WV    1990   1792548.0
#       2005   1820492.0
# WY    1990    453690.0
#       2005    514157.0
#
# [106 rows x 1 columns]

# %%
even_years = pops.index.get_level_values(1) % 2 == 0 
ends_in_a = pops.index.get_level_values(0)
pops.loc[:, even_years, :]

# %%
pops.loc[(slice(None), [1990,2005]), :]

# %%
pops.xs(1990, level="year")
# Out:
#         population
# state
# AK        553290.0
# AL       4050055.0
# AR       2356586.0
# AZ       3684097.0
# CA      29959515.0
# CO       3307618.0
# CT       3291967.0
# DC        605321.0
# DE        669567.0
# FL      13033307.0
# GA       6512602.0
# HI       1113491.0
# IA       2781018.0
# ID       1012384.0
# IL      11453316.0
# IN       5557798.0
# KS       2481349.0
# KY       3694048.0
# LA       4221532.0
# MA       6022639.0
# MD       4799770.0
# ME       1231719.0
# MI       9311319.0
# MN       4389857.0
# MO       5128880.0
# MS       2578897.0
# MT        800204.0
# NC       6664016.0
# ND        637685.0
# NE       1581660.0
# NH       1112384.0
# NJ       7762963.0
# NM       1521574.0
# NV       1220695.0
# NY      18020784.0
# OH      10864162.0
# OK       3148825.0
# OR       2860375.0
# PA      11903299.0
# PR             NaN
# RI       1005995.0
# SC       3501155.0
# SD        697101.0
# TN       4894492.0
# TX      17056755.0
# USA    249622814.0
# ...

# %%
pops
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(ascending=False)
# Out:
#             population
# state year
# WY    2013    582658.0
#       2012    576626.0
#       2011    567329.0
#       2010    564222.0
#       2009    559851.0
# ...                ...
# AK    1994    603308.0
#       1993    599434.0
#       1992    588736.0
#       1991    570193.0
#       1990    553290.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=[0,1], ascending=[False, True])
# Out:
#             population
# state year
# WY    1990    453690.0
#       1991    459260.0
#       1992    466251.0
#       1993    473081.0
#       1994    480283.0
# ...                ...
# AK    2009    698895.0
#       2010    713868.0
#       2011    723375.0
#       2012    730307.0
#       2013    735132.0
#
# [1272 rows x 1 columns]

# %%
pops.loc["WV",slice(2010,2013), :]
# Out:
#             population
# state year
# WV    2010   1854146.0
#       2011   1855184.0
#       2012   1856680.0
#       2013   1854304.0

# %%
pops.loc["WV",[2010,2011,2012,2013], :].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='state,year'>

# %%
states = pd.read_csv("data/state_pops.csv", index_col=0)

# %%
# Out:
#       year   population
# 0     2012    4817528.0
# 1     2010    4785570.0
# 2     2011    4801627.0
# 3     2009    4757938.0
# 4     2013    4833722.0
# ...    ...          ...
# 1267  2013  316128839.0
# 1268  2009  306771529.0
# 1269  2010  309326295.0
# 1270  2011  311582564.0
# 1271  2012  313873685.0
#
# [1272 rows x 2 columns]

# %%
# Out:
#        population
# year
# 2012    4817528.0
# 2010    4785570.0
# 2011    4801627.0
# 2009    4757938.0
# 2013    4833722.0
# ...           ...
# 2013  316128839.0
# 2009  306771529.0
# 2010  309326295.0
# 2011  311582564.0
# 2012  313873685.0
#
# [1272 rows x 1 columns]
