# %% [markdown]
# # Working With Text Data

# %%
import pandas as pd

# %%
titanic = pd.read_csv("data/titanic.csv")

# %%
titanic['age'] = titanic['age'].replace(['?'], [None]).astype('float')
titanic['fare'] = titanic['fare'].replace(['?'], [None]).astype('float')

# %% [markdown]
# ## Upper( ) and Lower( )

# %%
titanic["name"].str.upper()
# Out:
# 0                         ALLEN, MISS. ELISABETH WALTON
# 1                        ALLISON, MASTER. HUDSON TREVOR
# 2                          ALLISON, MISS. HELEN LORAINE
# 3                  ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4       ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
#                              ...
# 1304                               ZABOUR, MISS. HILENI
# 1305                              ZABOUR, MISS. THAMINE
# 1306                          ZAKARIAN, MR. MAPRIEDEDER
# 1307                                ZAKARIAN, MR. ORTIN
# 1308                                 ZIMMERMAN, MR. LEO
# Name: name, Length: 1309, dtype: object

# %%
titanic["name"]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic["lower_name"] = titanic["name"].str.lower()

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest  \
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
#                                            lower_name
# 0                       allen, miss. elisabeth walton
# 1                      allison, master. hudson trevor
# 2                        allison, miss. helen loraine
# 3                allison, mr. hudson joshua creighton
# 4     allison, mrs. hudson j c (bessie waldo daniels)
# ...                                               ...
# 1304                             zabour, miss. hileni
# 1305                            zabour, miss. thamine
# 1306                        zakarian, mr. mapriededer
# 1307                              zakarian, mr. ortin
# 1308                               zimmerman, mr. leo
#
# [1309 rows x 15 columns]

# %%
titanic.lower_name.str.capitalize()
# Out:
# 0                         Allen, miss. elisabeth walton
# 1                        Allison, master. hudson trevor
# 2                          Allison, miss. helen loraine
# 3                  Allison, mr. hudson joshua creighton
# 4       Allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               Zabour, miss. hileni
# 1305                              Zabour, miss. thamine
# 1306                          Zakarian, mr. mapriededer
# 1307                                Zakarian, mr. ortin
# 1308                                 Zimmerman, mr. leo
# Name: lower_name, Length: 1309, dtype: object

# %% [markdown]
# ## String Indexing

# %%
titanic["cabin"].str[0]
# Out:
# 0       B
# 1       C
# 2       C
# 3       C
# 4       C
#        ..
# 1304    ?
# 1305    ?
# 1306    ?
# 1307    ?
# 1308    ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic["deck"] = titanic["cabin"].str[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest  \
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
#                                            lower_name deck
# 0                       allen, miss. elisabeth walton    B
# 1                      allison, master. hudson trevor    C
# 2                        allison, miss. helen loraine    C
# 3                allison, mr. hudson joshua creighton    C
# 4     allison, mrs. hudson j c (bessie waldo daniels)    C
# ...                                               ...  ...
# 1304                             zabour, miss. hileni    ?
# 1305                            zabour, miss. thamine    ?
# 1306                        zakarian, mr. mapriededer    ?
# 1307                              zakarian, mr. ortin    ?
# 1308                               zimmerman, mr. leo    ?
#
# [1309 rows x 16 columns]

# %%
titanic.groupby("deck").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File E:\Python\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File E:\Python\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File E:\Python\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File E:\Python\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File E:\Python\Lib\site-packages\pandas\core\series.py:6540, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File E:\Python\Lib\site-packages\pandas\core\generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
#   12418         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12419     )
#
# File E:\Python\Lib\site-packages\pandas\core\generic.py:12374, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12372 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12374 return self._reduce(
#   12375     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376 )
#
# File E:\Python\Lib\site-packages\pandas\core\series.py:6448, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6444     raise TypeError(
#    6445         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6446         "with non-numeric dtypes."
#    6447     )
# -> 6448 return op(delegate, skipna=skipna, **kwds)
#
# File E:\Python\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File E:\Python\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File E:\Python\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File E:\Python\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'Artagaveytia, Mr. RamonBarber, Miss. Ellen 'Nellie'Baumann, Mr. John DBidois, Miss. RosalieBirnbaum, Mr. JakobBowen, Miss. Grace ScottBradley, Mr. George ('George Arthur Brayton')Brewe, Dr. Arthur JacksonCairns, Mr. AlexanderCandee, Mrs. Edward (Helen Churchill Hungerford)Carrau, Mr. Francisco MCarrau, Mr. Jose PedroCase, Mr. Howard BrownCassebeer, Mrs. Henry Arthur Jr (Eleanor Genevieve Fosdick)Chisholm, Mr. Roderick Robert CrispinCleaver, Miss. AliceCrafton, Mr. John BertramDaniel, Mr. Robert WilliamsDaniels, Miss. SarahFlegenheim, Mrs. Alfred (Antoinette)Fleming, Miss. MargaretFrauenthal, Dr. Henry WilliamFrauenthal, Mrs. Henry William (Clara Heinsheimer)Gibson, Miss. Dorothy WinifredGibson, Mrs. Leonard (Pauline C Boeson)Harrington, Mr. Charles HHolverson, Mr. Alexander OskarHolverson, Mrs. Alexander Oskar (Mary Aline Towner)Homer, Mr. Harry ('Mr E Haven')Hoyt, Mr. William FisherJones, Mr. Charles CressonKreuchen, Miss. EmilieLeRoy, Miss. BerthaLewy, Mr. Ervin GLindeberg-Lind, Mr. Erik Gustaf ('Mr Edward Lingrey')Lindstrom, Mrs. Carl Johan (Sigrid Posse)Loring, Mr. Joseph HollandMeyer, Mr. Edgar JosephMeyer, Mrs. Edgar Joseph (Leila Saks)Moore, Mr. Clarence BloomfieldNicholson, Mr. Arthur ErnestOmont, Mr. Alfred FernandParr, Mr. William Henry MarshReuchlin, Jonkheer. John GeorgeRheims, Mr. George Alexander LucienRinghini, Mr. SanteRobbins, Mr. VictorRomaine, Mr. Charles Hallace ('Mr C Rolmane')Rosenshine, Mr. George ('Mr George Thorne')Rothschild, Mr. MartinRothschild, Mrs. Martin (Elizabeth L. Barrett)Rowe, Mr. Alfred GSalomon, Mr. Abraham LSerepeca, Miss. AugustaSeward, Mr. Frederic KimberSmart, Mr. John MontgomeryStewart, Mr. Albert AThorne, Mrs. Gertrude MaybelleUruchurtu, Don. Manuel EWard, Miss. AnnaWeir, Col. JohnWick, Mr. George DennickWick, Mrs. George Dennick (Mary Hitchcock)Willard, Miss. ConstanceWilliams, Mr. Charles DuaneWilliams, Mr. Richard Norris IIWright, Mr. GeorgeAbelson, Mr. SamuelAbelson, Mrs. Samuel (Hannah Wizosky)Aldworth, Mr. Charles AugustusAndrew, Mr. Edgardo SamuelAndrew, Mr. Frank ThomasAngle, Mr. William AAngle, Mrs. William A (Florence 'Mary' Agnes Hughes)Ashby, Mr. JohnBailey, Mr. Percy AndrewBaimbrigge, Mr. Charles RobertBanfield, Mr. Frederick JamesBateman, Rev. Robert JamesBeane, Mr. EdwardBeane, Mrs. Edward (Ethel Clarke)Beauchamp, Mr. Henry JamesBentham, Miss. Lilian WBerriman, Mr. William JohnBotsford, Mr. William HullBowenur, Mr. SolomonBracken, Mr. James HBrown, Miss. Edith EileenBrown, Mr. Thomas William SolomonBrown, Mrs. Thomas William Solomon (Elizabeth Catherine Ford)Bryhl, Miss. Dagmar Jenny IngeborgBryhl, Mr. Kurt Arnold GottfridBuss, Miss. KateButler, Mr. Reginald FentonByles, Rev. Thomas Roussel DavidsBystrom, Mrs. (Karolina)Caldwell, Master. Alden GatesCaldwell, Mr. Albert FrancisCaldwell, Mrs. Albert Francis (Sylvia Mae Harbaugh)Cameron, Miss. Clear AnnieCampbell, Mr. WilliamCarbines, Mr. WilliamCarter, Mrs. Ernest Courtenay (Lilian Hughes)Carter, Rev. Ernest CourtenayChapman, Mr. Charles HenryChapman, Mr. John HenryChapman, Mrs. John Henry (Sara Elizabeth Lawry)Christy, Miss. Julie RachelChristy, Mrs. (Alice Frances)Clarke, Mr. Charles ValentineClarke, Mrs. Charles V (Ada Maria Winfield)Coleridge, Mr. Reginald CharlesCollander, Mr. Erik GustafCollett, Mr. Sidney C StuartCollyer, Miss. Marjorie 'Lottie'Collyer, Mr. HarveyCollyer, Mrs. Harvey (Charlotte Annie Tate)Corbett, Mrs. Walter H (Irene Colvin)Corey, Mrs. Percy C (Mary Phyllis Elizabeth Miller)Cotterill, Mr. Henry 'Harry'Cunningham, Mr. Alfred FlemingDavies, Master. John Morgan JrDavies, Mr. Charles HenryDavies, Mrs. John Morgan (Elizabeth Agnes Mary White)Davis, Miss. Maryde Brito, Mr. Jose JoaquimDeacon, Mr. Percy Williamdel Carlo, Mr. Sebastianodel Carlo, Mrs. Sebastiano (Argenia Genovesi)Denbury, Mr. HerbertDibden, Mr. WilliamDoling, Miss. ElsieDoling, Mrs. John T (Ada Julia Bone)Downton, Mr. William JamesDrew, Master. Marshall BrinesDrew, Mr. James VivianDrew, Mrs. James Viv ...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 titanic.groupby("deck").mean()
#
# File E:\Python\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File E:\Python\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File E:\Python\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File E:\Python\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File E:\Python\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File E:\Python\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
titanic.groupby("deck")["survived"].mean().sort_values().plot(kind="bar")

# %% [markdown]
# ## Strip( )

# %%
s = pd.Series(['1. Hawk.  ', '2. Pickle!\n', '3. Melonhead?\t'])

# %%
s
# Out:
# 0         1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.strip(to_strip="123. \n \t")
# Out:
# 0          Hawk
# 1       Pickle!
# 2    Melonhead?
# dtype: object

# %%
s.str.rstrip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.lstrip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip(to_strip="123.")
# Out:
# 0          Hawk.
# 1        Pickle!\n
# 2     Melonhead?\t
# dtype: object

# %% [markdown]
# ## Split( )

# %%
titanic["home.dest"].str.split("/", expand=True)
# Out:
#                   0                  1     2
# 0      St Louis, MO               None  None
# 1     Montreal, PQ    Chesterville, ON  None
# 2     Montreal, PQ    Chesterville, ON  None
# 3     Montreal, PQ    Chesterville, ON  None
# 4     Montreal, PQ    Chesterville, ON  None
# ...             ...                ...   ...
# 1304              ?               None  None
# 1305              ?               None  None
# 1306              ?               None  None
# 1307              ?               None  None
# 1308              ?               None  None
#
# [1309 rows x 3 columns]

# %%
titanic["home"] = titanic["home.dest"].str.split("/", expand=True)[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest  \
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
#                                            lower_name deck           home
# 0                       allen, miss. elisabeth walton    B   St Louis, MO
# 1                      allison, master. hudson trevor    C  Montreal, PQ
# 2                        allison, miss. helen loraine    C  Montreal, PQ
# 3                allison, mr. hudson joshua creighton    C  Montreal, PQ
# 4     allison, mrs. hudson j c (bessie waldo daniels)    C  Montreal, PQ
# ...                                               ...  ...            ...
# 1304                             zabour, miss. hileni    ?              ?
# 1305                            zabour, miss. thamine    ?              ?
# 1306                        zakarian, mr. mapriededer    ?              ?
# 1307                              zakarian, mr. ortin    ?              ?
# 1308                               zimmerman, mr. leo    ?              ?
#
# [1309 rows x 17 columns]

# %%
titanic["destination"] = titanic["home.dest"].str.split("/", expand=True)[1]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest  \
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
#                                            lower_name deck           home  \
# 0                       allen, miss. elisabeth walton    B   St Louis, MO
# 1                      allison, master. hudson trevor    C  Montreal, PQ
# 2                        allison, miss. helen loraine    C  Montreal, PQ
# 3                allison, mr. hudson joshua creighton    C  Montreal, PQ
# 4     allison, mrs. hudson j c (bessie waldo daniels)    C  Montreal, PQ
# ...                                               ...  ...            ...
# 1304                             zabour, miss. hileni    ?              ?
# 1305                            zabour, miss. thamine    ?              ?
# 1306                        zakarian, mr. mapriededer    ?              ?
# 1307                              zakarian, mr. ortin    ?              ?
# 1308                               zimmerman, mr. leo    ?              ?
#
#             destination
# 0                  None
# 1      Chesterville, ON
# 2      Chesterville, ON
# 3      Chesterville, ON
# 4      Chesterville, ON
# ...                 ...
# 1304               None
# 1305               None
# 1306               None
# 1307               None
# 1308               None
#
# [1309 rows x 18 columns]

# %%
titanic["home"].value_counts()
# Out:
# ?                           564
# New York, NY                 64
# Cornwall                     19
# London                       14
# London                       13
#                            ...
# Middleburg Heights, OH        1
# Barre, Co Washington, VT      1
# Oslo, Norway Bayonne, NJ      1
# England Oglesby, IL           1
# ?Havana, Cuba                 1
# Name: home, Length: 339, dtype: int64

# %%
titanic["destination"].value_counts()
# Out:
#  Akron, OH          11
#  Montreal, PQ        9
#  New York, NY        9
#  Detroit, MI         6
#  Cooperstown, NY     5
#                     ..
#  Pennsylvania        1
#  Greenwich CT        1
#  Arlington, NJ       1
#  Toledo, OH          1
#  Birmingham          1
# Name: destination, Length: 77, dtype: int64

# %%
titanic["home.dest"].str.split("/", n=1, expand=True)
# Out:
#                   0                  1
# 0      St Louis, MO               None
# 1     Montreal, PQ    Chesterville, ON
# 2     Montreal, PQ    Chesterville, ON
# 3     Montreal, PQ    Chesterville, ON
# 4     Montreal, PQ    Chesterville, ON
# ...             ...                ...
# 1304              ?               None
# 1305              ?               None
# 1306              ?               None
# 1307              ?               None
# 1308              ?               None
#
# [1309 rows x 2 columns]

# %% [markdown]
# ## Replace( )

# %%
ufos = pd.read_csv("data/nuforc_reports.csv")

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# 0        VA  2019-12-12T18:43:00      light    5 seconds
# 1        CT  2019-03-22T18:30:00     circle  3-5 seconds
# 2       NaN                  NaN        NaN          NaN
# 3        ON  2019-04-17T02:00:00   teardrop   10 seconds
# 4        NY  2009-03-15T18:00:00      cigar    2 minutes
# ...     ...                  ...        ...          ...
# 88120    AZ  2019-10-02T20:00:00  formation    3 minutes
# 88121    MO  2019-10-02T20:00:00      light   20 seconds
# 88122    FL  2019-10-02T20:03:00  formation   20 seconds
# 88123    NC  2019-10-02T22:00:00   fireball    2 minutes
# 88124    CA  2019-10-02T22:00:00     sphere    3 minutes
#
#                                                    stats  \
# 0      Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1      Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2      Occurred : 4/1/2019 15:45  (Entered as : April...
# 3      Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 4      Occurred : 3/15/2009 18:00  (Entered as : 03/1...
# ...                                                  ...
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# 88122  Occurred : 10/2/2019 20:03  (Entered as : 10/0...
# 88123  Occurred : 10/2/2019 22:00  (Entered as : 10/0...
# 88124  Occurred : 10/2/2019 22:00  (Entered as : 10-0...
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 2      http://www.nuforc.org/webreports/145/S145556.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 4      http://www.nuforc.org/webreports/145/S145723.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                                                     text               posted  \
# 0      My wife was driving southeast on a fairly popu...  2019-12-22T00:00:00
# 1      I think that I may caught a UFO on the NBC Nig...  2019-03-29T00:00:00
# 2      I woke up late in the afternoon 3:30-4pm.  I w...                  NaN
# 3      I was driving towards the intersection of fall...  2019-04-18T00:00:00
# 4      In Peoria, Arizona, I saw a cigar shaped craft...  2019-04-18T00:00:00
# ...                                                  ...                  ...
# 88120  4 lights in formation over Tempe appear while ...  2019-10-04T00:00:00
# 88121  2 bright star like lights in the NNW sky two b...  2019-10-04T00:00:00
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  2019-10-04T00:00:00
# 88123  Witnessed an orange, slow moving light. Was lo...  2019-10-04T00:00:00
# 88124  Glowing lights in formation  just south of San...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 0          37.343152      -77.408582
# 1          41.664800      -72.639300
# 2                NaN             NaN
# 3          45.381383      -75.708501
# 4                NaN             NaN
# ...              ...             ...
# 88120      33.414036     -111.920920
# 88121      37.642200      -93.399600
# 88122      27.076210      -82.223280
# 88123      35.605000      -82.313200
# 88124            NaN             NaN
#
# [88125 rows x 12 columns]

# %%
ufos["duration"]
# Out:
# 0          5 seconds
# 1        3-5 seconds
# 2                NaN
# 3         10 seconds
# 4          2 minutes
#             ...
# 88120      3 minutes
# 88121     20 seconds
# 88122     20 seconds
# 88123      2 minutes
# 88124      3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds", "s")
# Out:
# 0              5 s
# 1            3-5 s
# 2              NaN
# 3             10 s
# 4        2 minutes
#            ...
# 88120    3 minutes
# 88121         20 s
# 88122         20 s
# 88123    2 minutes
# 88124    3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds|minutes", "", regex=True)
# Out:
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %%
def abbrv(reo):
    return reo.group()[0]

# %%
ufos["duration"].str.replace("seconds|minutes|hours", abbrv)
# Out:
# <ipython-input-269-dce69a0bac36>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ufos["duration"].str.replace("seconds|minutes|hours", abbrv)
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %% [markdown]
# ## Contains( )

# %%
ufos["duration"].str.contains("hour")
# Out:
# 0        False
# 1        False
# 2          NaN
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: object

# %%
ufos[ufos["duration"].str.contains("day|week|month", na=False)]
# Out:
#                                                  summary  \
# 107    7 large yellow lights with red center  estimat...
# 116    Saw one large ship during the day around noon ...
# 286    film makers in hollywood where talking of film...
# 290                               End of the Century UFO
# 1355   A white ball of light made several appearances...
# ...                                                  ...
# 84021  The Beings and Craft of Taos County.  ((NUFORC...
# 84983  In 1967 I am a little kid now. I am sleeping I...
# 85717  There was a big bright colored triangle object...
# 86210  2 flying diamonds; red and gold lights; creaki...
# 87707  Lights seen from the night sky 1st night-flick...
#
#                           city state            date_time      shape  \
# 107                    Griffin    GA  1984-03-15T20:00:00     circle
# 116                  Knoxville    TN  1986-04-04T23:00:00  rectangle
# 286                    Arizona    AZ  1997-07-07T00:00:00   triangle
# 290    Cebu City (Philippines)   NaN  1998-03-01T20:00:00      other
# 1355                     Genoa    IL  2007-01-25T22:00:00     sphere
# ...                        ...   ...                  ...        ...
# 84021                     Taos    NM  2019-09-01T10:00:00      other
# 84983                   Saugas    CA                  NaN        NaN
# 85717                  Houston    BC  2019-11-25T03:30:00   triangle
# 86210                   Dallas    TX  2019-10-11T01:44:00    diamond
# 87707                    Haiku    HI  2019-11-25T00:00:00      light
#
#             duration                                              stats  \
# 107         3 months  Occurred : 3/15/1984 20:00  (Entered as : marc...
# 116             week  Occurred : 4/4/1986 23:00  (Entered as : 03150...
# 286       all months  Occurred : 7/7/1997   (Entered as : 7 7 1997) ...
# 290    1 to 2 months  Occurred : 3/1/1998 20:00  (Entered as : 03/01...
# 1355        5 months  Occurred : 1/25/2007 22:00  (Entered as : 01/2...
# ...              ...                                                ...
# 84021         2 days  Occurred : 9/1/2019 10:00  (Entered as : 09/01...
# 84983         3 days  Occurred : 6/30/1967 04:00 Reported: 12/19/201...
# 85717  Till daylight  Occurred : 11/25/2019 03:30  (Entered as : 11/...
# 86210         2 days  Occurred : 10/11/2019 01:44  (Entered as : 10/...
# 87707         4 days  Occurred : 11/25/2019  Reported: 11/29/2019 7:...
#
#                                              report_link  \
# 107     http://www.nuforc.org/webreports/050/S50375.html
# 116     http://www.nuforc.org/webreports/049/S49786.html
# 286     http://www.nuforc.org/webreports/049/S49553.html
# 290     http://www.nuforc.org/webreports/050/S50203.html
# 1355   http://www.nuforc.org/webreports/146/S146567.html
# ...                                                  ...
# 84021  http://www.nuforc.org/webreports/148/S148913.html
# 84983  http://www.nuforc.org/webreports/144/S144137.html
# 85717  http://www.nuforc.org/webreports/151/S151095.html
# 86210  http://www.nuforc.org/webreports/150/S150378.html
# 87707  http://www.nuforc.org/webreports/151/S151166.html
#
#                                                     text               posted  \
# 107    7 large yellow lights with red center  estimat...  2006-05-15T00:00:00
# 116    Saw one large ship during the day around noon ...  2006-05-15T00:00:00
# 286    film makers in hollywood where talking of film...  2006-05-15T00:00:00
# 290    End of the Century UFO First of all I'd like t...  2006-05-15T00:00:00
# 1355   A white ball of light made several appearances...  2019-06-07T00:00:00
# ...                                                  ...                  ...
# 84021  The Beings and Craft of Taos County. ((NUFORC ...  2019-09-19T00:00:00
# 84983  In 1967 I am a little kid now.  I am sleeping ...                  NaN
# 85717  There was a big bright colored triangle object...  2019-12-01T00:00:00
# 86210  2 flying diamonds; red and gold lights; creaki...  2019-12-01T00:00:00
# 87707  Lights seen from the night sky 1st night-flick...  2019-12-01T00:00:00
#
#        city_latitude  city_longitude
# 107        33.248869      -84.249217
# 116        35.961561      -83.980115
# 286              NaN             NaN
# 290              NaN             NaN
# 1355       42.108600      -88.686000
# ...              ...             ...
# 84021      36.414600     -105.522200
# 84983            NaN             NaN
# 85717      54.400000     -126.650000
# 86210      32.835168      -96.808118
# 87707      20.858800     -156.140500
#
# [204 rows x 12 columns]
