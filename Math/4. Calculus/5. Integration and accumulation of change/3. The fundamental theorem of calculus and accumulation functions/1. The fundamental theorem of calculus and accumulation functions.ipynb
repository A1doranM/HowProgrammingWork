# %% [markdown]
# # Contents
#
# [The Fundamental Theorem of Calculus and Accumulation Functions](#the-fundamental-theorem-of-calculus-and-accumulation-functions)
#
# [Finding antiderivative of a Function](#finding-antiderivative-of-a-function)
#
# [Finding derivative with fundamental theorem of calculus: chain rule](#finding-derivative-with-fundamental-theorem-of-calculus-chain-rule)

# %% [markdown]
# # The fundamental theorem of calculus and accumulation functions

# %% [markdown]
# ![](./images/img.png)
#
# ![](./images/img_1.png)
#
# ![](./images/img_2.png)
#
# ![](./images/img_3.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the original function f(x) and its antiderivative F(x)
def f(x):
    return x**2  # The original function

def F(x):
    return x**3 / 3  # The antiderivative

# Define the interval and points for the graph
x = np.linspace(0, 3, 500)  # Interval [0, 3]
x_accum = np.linspace(0, 3, 100)  # Points for accumulation

# Compute values for accumulation
F_values = F(x_accum)

# Plot the original function and the accumulation function
plt.figure(figsize=(10, 6))

# Plot f(x)
plt.subplot(2, 1, 1)
plt.plot(x, f(x), label=r"$f(x) = x^2$", color="blue")
plt.title("Original Function and Accumulation Function")
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(alpha=0.3)

# Plot F(x) = ∫ f(t) dt
plt.subplot(2, 1, 2)
plt.plot(x_accum, F_values, label=r"$F(x) = \int_0^x t^2 dt$", color="green")
plt.fill_between(x_accum, 0, F_values, color="green", alpha=0.2, label="Accumulated Area")
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.xlabel("x")
plt.ylabel("Accumulation: F(x)")
plt.legend()
plt.grid(alpha=0.3)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Finding antiderivative of a function

# %% [markdown]
# ![](./images/img_4.png)
#
# ![](./images/img_5.png)
#
# ![](./images/img_6.png)
#
# ![](./images/img_7.png)

# %%
# Importing necessary libraries
import sympy as sp

# Define the variable and the function
x = sp.Symbol('x')
function = 3*x**2 + 4*x - 5

# Finding the antiderivative (indefinite integral)
antiderivative = sp.integrate(function, x)
print(f"Antiderivative of the function: {antiderivative}")

# Evaluating the definite integral from x=1 to x=3
definite_integral = sp.integrate(function, (x, 1, 3))
print(f"Definite integral of the function from x=1 to x=3: {definite_integral}")

# Illustrating the function and the area under the curve using matplotlib
import numpy as np
import matplotlib.pyplot as plt

# Define the function as a lambda for numerical operations
f = lambda x: 3*x**2 + 4*x - 5

# Define the range for plotting
x_vals = np.linspace(0, 4, 100)
y_vals = f(x_vals)

# Plot the function
plt.figure(figsize=(8, 6))
plt.plot(x_vals, y_vals, label='$f(x) = 3x^2 + 4x - 5$', color='blue')

# Fill the area under the curve between x=1 and x=3
x_fill = np.linspace(1, 3, 100)
y_fill = f(x_fill)
plt.fill_between(x_fill, y_fill, color='lightblue', alpha=0.5, label='Area under $f(x)$ from 1 to 3')

# Add labels, legend, and title
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Function and Area Under the Curve')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.legend()
plt.grid()
plt.show()
# Out:
# Antiderivative of the function: x**3 + 2*x**2 - 5*x
# Definite integral of the function from x=1 to x=3: 32

# %% [markdown]
# # Finding derivative with fundamental theorem of calculus: chain rule

# %% [markdown]
# ![](./images/img_8.png)
#
# ![](./images/img_9.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, diff, integrate, sin

# Define the variable and the function
x = symbols('x')
t = symbols('t')

# Define the integral
g = x**2  # Upper limit
f = sin(t)  # Function inside the integral
integral = integrate(f, (t, 1, g))

# Compute the derivative
derivative = diff(integral, x)
print(f"Integral: {integral}")
print(f"Derivative: {derivative}")

# Plot the derivative and the function
x_vals = np.linspace(-2, 2, 400)
f_derivative = 2 * x_vals * np.sin(x_vals**2)

plt.plot(x_vals, f_derivative, label="Derivative of F(x)")
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title("Derivative of the Function Using the Fundamental Theorem")
plt.xlabel("x")
plt.ylabel("F'(x)")
plt.legend()
plt.show()
# Out:
# Integral: -cos(x**2) + cos(1)
# Derivative: 2*x*sin(x**2)

# %% [markdown]
# # Interpreting the behavior of accumulation functions

# %% [markdown]
# ![](./images/img_10.png)
#
# ![](./images/img_11.png)
#
# ![](./images/img_12.png)
#
# ![](./images/img_13.png)
