# %% [markdown]
# # Initial Inspection and Visualisation

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use('seaborn-whitegrid')
# Out:
# /tmp/ipykernel_125178/1020506351.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
df = pd.read_csv('multi_assets.csv', header=[0, 1], index_col=0, parse_dates=True)
df
# Out:
# Price                     Adj Close                                           \
# Ticker                           BA    BTC-USD EURUSD=X      GC=F       ^DJI
# Date
# 2014-10-21 00:00:00+00:00  110.5370   386.4750   1.2795 1251.0000 16614.8105
# 2014-10-22 00:00:00+00:00  105.6067   383.1580   1.2715 1244.8000 16461.3203
# 2014-10-23 00:00:00+00:00  106.1111   358.4170   1.2641 1228.5000 16677.9004
# 2014-10-24 00:00:00+00:00  106.2937   358.3450   1.2654 1231.2000 16805.4102
# 2014-10-25 00:00:00+00:00       NaN   347.2710      NaN       NaN        NaN
# ...                             ...        ...      ...       ...        ...
# 2024-10-16 00:00:00+00:00  154.9000 67612.7188   1.0884 2674.0000 43077.6992
# 2024-10-17 00:00:00+00:00  155.3100 67399.8359   1.0862 2691.0000 43239.0508
# 2024-10-18 00:00:00+00:00  155.0000 68418.7891   1.0830 2713.7000 43275.9102
# 2024-10-19 00:00:00+00:00       NaN 68362.7344      NaN       NaN        NaN
# 2024-10-20 00:00:00+00:00       NaN 69001.7031      NaN       NaN        NaN
#
# Price                        Close                                           \
# Ticker                          BA    BTC-USD EURUSD=X      GC=F       ^DJI
# Date
# 2014-10-21 00:00:00+00:00 127.1200   386.4750   1.2795 1251.0000 16614.8105
# 2014-10-22 00:00:00+00:00 121.4500   383.1580   1.2715 1244.8000 16461.3203
# 2014-10-23 00:00:00+00:00 122.0300   358.4170   1.2641 1228.5000 16677.9004
# 2014-10-24 00:00:00+00:00 122.2400   358.3450   1.2654 1231.2000 16805.4102
# 2014-10-25 00:00:00+00:00      NaN   347.2710      NaN       NaN        NaN
# ...                            ...        ...      ...       ...        ...
# 2024-10-16 00:00:00+00:00 154.9000 67612.7188   1.0884 2674.0000 43077.6992
# 2024-10-17 00:00:00+00:00 155.3100 67399.8359   1.0862 2691.0000 43239.0508
# 2024-10-18 00:00:00+00:00 155.0000 68418.7891   1.0830 2713.7000 43275.9102
# 2024-10-19 00:00:00+00:00      NaN 68362.7344      NaN       NaN        NaN
# 2024-10-20 00:00:00+00:00      NaN 69001.7031      NaN       NaN        NaN
#
# Price                      ...     Open                                \
# Ticker                     ...       BA    BTC-USD EURUSD=X      GC=F
# Date                       ...
# 2014-10-21 00:00:00+00:00  ... 125.2100   382.4210   1.2795 1251.0000
# 2014-10-22 00:00:00+00:00  ... 127.9900   386.1180   1.2714 1244.8000
# 2014-10-23 00:00:00+00:00  ... 121.2700   382.9620   1.2645 1228.0000
# 2014-10-24 00:00:00+00:00  ... 122.2000   358.5910   1.2651 1229.4000
# 2014-10-25 00:00:00+00:00  ...      NaN   358.6110      NaN       NaN
# ...                        ...      ...        ...      ...       ...
# 2024-10-16 00:00:00+00:00  ... 151.9100 67042.4609   1.0884 2674.0000
# 2024-10-17 00:00:00+00:00  ... 155.0000 67617.0781   1.0862 2677.3999
# 2024-10-18 00:00:00+00:00  ... 155.8400 67419.1094   1.0830 2713.7000
# 2024-10-19 00:00:00+00:00  ...      NaN 68418.9766      NaN       NaN
# 2024-10-20 00:00:00+00:00  ...      NaN 68364.1797      NaN       NaN
#
# Price                                       Volume                        \
# Ticker                          ^DJI            BA      BTC-USD EURUSD=X
# Date
# 2014-10-21 00:00:00+00:00 16406.0293  5204500.0000     14188900   0.0000
# 2014-10-22 00:00:00+00:00 16615.2598 13844400.0000     11641300   0.0000
# 2014-10-23 00:00:00+00:00 16468.0703  7799700.0000     26456900   0.0000
# 2014-10-24 00:00:00+00:00 16677.0391  4013300.0000     15585700   0.0000
# 2014-10-25 00:00:00+00:00        NaN           NaN     18127500      NaN
# ...                              ...           ...          ...      ...
# 2024-10-16 00:00:00+00:00 42706.4883  8356200.0000  38195189534   0.0000
# 2024-10-17 00:00:00+00:00 43119.8086  6291800.0000  32790898511   0.0000
# 2024-10-18 00:00:00+00:00 43187.1211  6025200.0000  36857165014   0.0000
# 2024-10-19 00:00:00+00:00        NaN           NaN  14443497908      NaN
# 2024-10-20 00:00:00+00:00        NaN           NaN  18975847518      NaN
#
# Price
# Ticker                       GC=F           ^DJI
# Date
# 2014-10-21 00:00:00+00:00 48.0000 105110000.0000
# 2014-10-22 00:00:00+00:00  2.0000  92050000.0000
# 2014-10-23 00:00:00+00:00  2.0000  99420000.0000
# 2014-10-24 00:00:00+00:00 71.0000  90400000.0000
# 2014-10-25 00:00:00+00:00     NaN            NaN
# ...                           ...            ...
# 2024-10-16 00:00:00+00:00  6.0000 297510000.0000
# 2024-10-17 00:00:00+00:00 30.0000 267370000.0000
# 2024-10-18 00:00:00+00:00 30.0000 295500000.0000
# 2024-10-19 00:00:00+00:00     NaN            NaN
# 2024-10-20 00:00:00+00:00     NaN            NaN
#
# [3653 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3653 entries, 2014-10-21 00:00:00+00:00 to 2024-10-20 00:00:00+00:00
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        2516 non-null   float64
#  1   (Adj Close, BTC-USD)   3653 non-null   float64
#  2   (Adj Close, EURUSD=X)  2605 non-null   float64
#  3   (Adj Close, GC=F)      2513 non-null   float64
#  4   (Adj Close, ^DJI)      2516 non-null   float64
#  5   (Close, BA)            2516 non-null   float64
#  6   (Close, BTC-USD)       3653 non-null   float64
#  7   (Close, EURUSD=X)      2605 non-null   float64
#  8   (Close, GC=F)          2513 non-null   float64
#  9   (Close, ^DJI)          2516 non-null   float64
#  10  (High, BA)             2516 non-null   float64
#  11  (High, BTC-USD)        3653 non-null   float64
#  12  (High, EURUSD=X)       2605 non-null   float64
#  13  (High, GC=F)           2513 non-null   float64
#  14  (High, ^DJI)           2516 non-null   float64
#  15  (Low, BA)              2516 non-null   float64
#  16  (Low, BTC-USD)         3653 non-null   float64
#  17  (Low, EURUSD=X)        2605 non-null   float64
#  18  (Low, GC=F)            2513 non-null   float64
#  19  (Low, ^DJI)            2516 non-null   float64
#  20  (Open, BA)             2516 non-null   float64
#  21  (Open, BTC-USD)        3653 non-null   float64
#  22  (Open, EURUSD=X)       2605 non-null   float64
#  23  (Open, GC=F)           2513 non-null   float64
#  24  (Open, ^DJI)           2516 non-null   float64
#  25  (Volume, BA)           2516 non-null   float64
#  26  (Volume, BTC-USD)      3653 non-null   int64
#  27  (Volume, EURUSD=X)     2605 non-null   float64
#  28  (Volume, GC=F)         2513 non-null   float64
#  29  (Volume, ^DJI)         2516 non-null   float64
# dtypes: float64(29), int64(1)
# memory usage: 884.7 KB

# %%
df.loc[:, ("Close", "BA")]
# Out:
# Date
# 2014-10-21 00:00:00+00:00   127.1200
# 2014-10-22 00:00:00+00:00   121.4500
# 2014-10-23 00:00:00+00:00   122.0300
# 2014-10-24 00:00:00+00:00   122.2400
# 2014-10-25 00:00:00+00:00        NaN
#                               ...
# 2024-10-16 00:00:00+00:00   154.9000
# 2024-10-17 00:00:00+00:00   155.3100
# 2024-10-18 00:00:00+00:00   155.0000
# 2024-10-19 00:00:00+00:00        NaN
# 2024-10-20 00:00:00+00:00        NaN
# Name: (Close, BA), Length: 3653, dtype: float64

# %%
df = df.swaplevel(axis="columns").sort_index(axis="columns")

# %%
df["BTC-USD"]
# Out:
# Price                      Adj Close      Close       High        Low  \
# Date
# 2014-10-21 00:00:00+00:00   386.4750   386.4750   392.6460   380.8340
# 2014-10-22 00:00:00+00:00   383.1580   383.1580   388.5760   382.2490
# 2014-10-23 00:00:00+00:00   358.4170   358.4170   385.0480   356.4470
# 2014-10-24 00:00:00+00:00   358.3450   358.3450   364.3450   353.3050
# 2014-10-25 00:00:00+00:00   347.2710   347.2710   359.8610   342.8770
# ...                              ...        ...        ...        ...
# 2024-10-16 00:00:00+00:00 67612.7188 67612.7188 68375.2891 66758.7266
# 2024-10-17 00:00:00+00:00 67399.8359 67399.8359 67912.2109 66647.3906
# 2024-10-18 00:00:00+00:00 68418.7891 68418.7891 68969.7500 67177.8203
# 2024-10-19 00:00:00+00:00 68362.7344 68362.7344 68668.0078 68024.6406
# 2024-10-20 00:00:00+00:00 69001.7031 69001.7031 69359.0078 68105.7188
#
# Price                           Open       Volume
# Date
# 2014-10-21 00:00:00+00:00   382.4210     14188900
# 2014-10-22 00:00:00+00:00   386.1180     11641300
# 2014-10-23 00:00:00+00:00   382.9620     26456900
# 2014-10-24 00:00:00+00:00   358.5910     15585700
# 2014-10-25 00:00:00+00:00   358.6110     18127500
# ...                              ...          ...
# 2024-10-16 00:00:00+00:00 67042.4609  38195189534
# 2024-10-17 00:00:00+00:00 67617.0781  32790898511
# 2024-10-18 00:00:00+00:00 67419.1094  36857165014
# 2024-10-19 00:00:00+00:00 68418.9766  14443497908
# 2024-10-20 00:00:00+00:00 68364.1797  18975847518
#
# [3653 rows x 6 columns]

# %%
df = df.swaplevel(axis="columns").sort_index(axis="columns")

# %%
close = df.Close.copy()

# %%
close
# Out:
# Ticker                          BA    BTC-USD  EURUSD=X      GC=F       ^DJI
# Date
# 2014-10-21 00:00:00+00:00 127.1200   386.4750    1.2795 1251.0000 16614.8105
# 2014-10-22 00:00:00+00:00 121.4500   383.1580    1.2715 1244.8000 16461.3203
# 2014-10-23 00:00:00+00:00 122.0300   358.4170    1.2641 1228.5000 16677.9004
# 2014-10-24 00:00:00+00:00 122.2400   358.3450    1.2654 1231.2000 16805.4102
# 2014-10-25 00:00:00+00:00      NaN   347.2710       NaN       NaN        NaN
# ...                            ...        ...       ...       ...        ...
# 2024-10-16 00:00:00+00:00 154.9000 67612.7188    1.0884 2674.0000 43077.6992
# 2024-10-17 00:00:00+00:00 155.3100 67399.8359    1.0862 2691.0000 43239.0508
# 2024-10-18 00:00:00+00:00 155.0000 68418.7891    1.0830 2713.7000 43275.9102
# 2024-10-19 00:00:00+00:00      NaN 68362.7344       NaN       NaN        NaN
# 2024-10-20 00:00:00+00:00      NaN 69001.7031       NaN       NaN        NaN
#
# [3653 rows x 5 columns]

# %%
close.describe()
# Out:
# Ticker        BA    BTC-USD  EURUSD=X      GC=F       ^DJI
# count  2516.0000  3653.0000 2605.0000 2513.0000  2516.0000
# mean    217.2833 18399.0516    1.1228 1574.2015 27179.9525
# std      80.5276 20032.9539    0.0545  366.7919  7082.1896
# min      95.0100   178.1030    0.9596 1050.8000 15660.1797
# 25%     149.7775  1255.1500    1.0863 1253.3000 20875.6577
# 50%     197.4950  9278.8076    1.1171 1493.2000 26409.0303
# 75%     255.6550 29799.0801    1.1620 1852.3000 33699.9795
# max     440.6200 73083.5000    1.2795 2713.7000 43275.9102

# %%
close.BA.dropna().plot(figsize=(15, 8), fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
close.dropna().plot(figsize=(15, 8), fontsize=13)
plt.legend(fontsize=13)
plt.show()
