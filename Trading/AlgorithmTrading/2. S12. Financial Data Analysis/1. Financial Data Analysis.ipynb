# %% [markdown]
# # Financial Data Analysis

# %%
import pandas as pd
import yfinance as yf

# %%
start = '2014-10-21'
end = '2024-10-21'

# %%
symbol = "BA"

# %%
yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                             BA          BA          BA          BA
# Date
# 2014-10-21 00:00:00+00:00  110.537048  127.120003  127.239998  124.930000
# 2014-10-22 00:00:00+00:00  105.606728  121.449997  128.000000  121.339996
# 2014-10-23 00:00:00+00:00  106.111069  122.029999  122.879997  121.059998
# 2014-10-24 00:00:00+00:00  106.293655  122.239998  122.839996  121.260002
# 2014-10-27 00:00:00+00:00  106.189331  122.120003  122.230003  121.260002
# ...                               ...         ...         ...         ...
# 2024-10-14 00:00:00+00:00  148.990005  148.990005  150.089996  146.020004
# 2024-10-15 00:00:00+00:00  152.350006  152.350006  153.949997  148.550003
# 2024-10-16 00:00:00+00:00  154.899994  154.899994  154.990005  151.339996
# 2024-10-17 00:00:00+00:00  155.309998  155.309998  157.139999  154.250000
# ...

# %%
df = yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2014-10-21 00:00:00+00:00 to 2024-10-18 00:00:00+00:00
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Adj Close, BA)  2516 non-null   float64
#  1   (Close, BA)      2516 non-null   float64
#  2   (High, BA)       2516 non-null   float64
#  3   (Low, BA)        2516 non-null   float64
#  4   (Open, BA)       2516 non-null   float64
#  5   (Volume, BA)     2516 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 137.6 KB

# %%
symbol = ["BA", "^DJI", "EURUSD=X", "GC=F", "BTC-USD"]

# %%
df = yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
df
# Out:
# Price                       Adj Close                                       \
# Ticker                             BA       BTC-USD  EURUSD=X         GC=F
# Date
# 2014-10-21 00:00:00+00:00  110.537048    386.475006  1.279525  1251.000000
# 2014-10-22 00:00:00+00:00  105.606728    383.157990  1.271472  1244.800049
# 2014-10-23 00:00:00+00:00  106.111069    358.416992  1.264143  1228.500000
# 2014-10-24 00:00:00+00:00  106.293655    358.345001  1.265406  1231.199951
# 2014-10-25 00:00:00+00:00         NaN    347.270996       NaN          NaN
# ...                               ...           ...       ...          ...
# 2024-10-16 00:00:00+00:00  154.899994  67612.718750  1.088412  2674.000000
# 2024-10-17 00:00:00+00:00  155.309998  67399.835938  1.086248  2691.000000
# 2024-10-18 00:00:00+00:00  155.000000  68418.789062  1.082954  2713.699951
# 2024-10-19 00:00:00+00:00         NaN  68362.734375       NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3653 entries, 2014-10-21 00:00:00+00:00 to 2024-10-20 00:00:00+00:00
# Freq: D
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        2516 non-null   float64
#  1   (Adj Close, BTC-USD)   3653 non-null   float64
#  2   (Adj Close, EURUSD=X)  2605 non-null   float64
#  3   (Adj Close, GC=F)      2513 non-null   float64
#  4   (Adj Close, ^DJI)      2516 non-null   float64
#  5   (Close, BA)            2516 non-null   float64
#  6   (Close, BTC-USD)       3653 non-null   float64
#  7   (Close, EURUSD=X)      2605 non-null   float64
#  8   (Close, GC=F)          2513 non-null   float64
#  9   (Close, ^DJI)          2516 non-null   float64
#  10  (High, BA)             2516 non-null   float64
#  11  (High, BTC-USD)        3653 non-null   float64
#  12  (High, EURUSD=X)       2605 non-null   float64
# ...

# %%
df.to_csv("multi_assets.csv")
