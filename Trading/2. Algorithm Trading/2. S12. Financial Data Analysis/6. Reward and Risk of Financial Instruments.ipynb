# %% [markdown]
# # Reward and Risk of financial Instruments

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
BA = pd.read_csv('ba_csv.csv', index_col = "Date", parse_dates=["Date"])

# %%
BA
# Out:
#                                 Price   Returns
# Date
# 2014-10-21 00:00:00+00:00  127.120003       NaN
# 2014-10-22 00:00:00+00:00  121.449997 -0.044604
# 2014-10-23 00:00:00+00:00  122.029999  0.004776
# 2014-10-24 00:00:00+00:00  122.239998  0.001721
# 2014-10-27 00:00:00+00:00  122.120003 -0.000982
# ...                               ...       ...
# 2024-10-14 00:00:00+00:00  148.990005 -0.013442
# 2024-10-15 00:00:00+00:00  152.350006  0.022552
# 2024-10-16 00:00:00+00:00  154.899994  0.016738
# 2024-10-17 00:00:00+00:00  155.309998  0.002647
# 2024-10-18 00:00:00+00:00  155.000000 -0.001996
#
# [2516 rows x 2 columns]

# %%
BA.Price.plot(figsize=(15,8), fontsize=16)
plt.show()

# %% [markdown]
# - Reward: Positive Returns
# - Risk: Volatility of Returns

# %%
BA.describe()
# Out:
#              Price      Returns
# count  2516.000000  2515.000000
# mean    217.283299     0.000399
# std      80.527555     0.025300
# min      95.010002    -0.238484
# 25%     149.777500    -0.010068
# 50%     197.495003     0.000291
# 75%     255.654995     0.010768
# max     440.619995     0.243186

# %%
AM = BA.Returns.mean() # arithmetic mean return -> Reward
AM
# Out:
# 0.0003994943930349097

# %%
sigma = BA.Returns.std() # standard deviation of returns -> Risk/Volatility
sigma
# Out:
# 0.025300055205998654

# %%
np.sqrt(BA.Returns.var())
# Out:
# 0.025300055205998654
