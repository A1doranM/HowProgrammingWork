# %% [markdown]
# # Working with two or many Strategies (Combination)

# %% [markdown]
# ## Introduction and Data

# %% [markdown]
# Measures to reduce Trading Costs:
# - Busy Trading Hours
# - The right Granularity
# - Better/more complex Strategies with stronger Signals -> go/stay neutral if signals are weak

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
df = pd.read_csv("twenty_minutes.csv", parse_dates = ["time"], index_col = "time")
df
# Out:
#                              EURUSD    GBPUSD    EURAUD
# time
# 2019-01-01 22:00:00+00:00  1.146320  1.274770  1.626290
# 2019-01-01 22:20:00+00:00  1.146455  1.274740  1.626695
# 2019-01-01 22:40:00+00:00  1.146410  1.273980  1.627340
# 2019-01-01 23:00:00+00:00  1.146670  1.275030  1.626540
# 2019-01-01 23:20:00+00:00  1.146630  1.275150  1.627450
# ...                             ...       ...       ...
# 2020-08-30 22:20:00+00:00  1.190970  1.334830  1.616940
# 2020-08-30 22:40:00+00:00  1.190860  1.334515  1.617120
# 2020-08-30 23:00:00+00:00  1.190690  1.334905  1.617360
# 2020-08-30 23:20:00+00:00  1.190895  1.335140  1.617190
# 2020-08-30 23:40:00+00:00  1.191715  1.335490  1.616945
#
# [31026 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 31026 entries, 2019-01-01 22:00:00+00:00 to 2020-08-30 23:40:00+00:00
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EURUSD  31017 non-null  float64
#  1   GBPUSD  31024 non-null  float64
#  2   EURAUD  31021 non-null  float64
# dtypes: float64(3)
# memory usage: 969.6 KB

# %% [markdown]
# ## SMA Strategy

# %%
import SMABacktester as SMA

# %%
start = "2019-01-01"
end = "2020-08-30"
symbol = "EURUSD"
sma_s = 50
sma_l = 150
tc = 0.00007

# %%
tester = SMA.SMABacktester(symbol, sma_s, sma_l, start, end, tc)

# %%
tester
# Out:
# SMABacktester(symbol = EURUSD, SMA_S = 50, SMA_L = 150, start = 2019-01-01, end = 2020-08-30)

# %%
tester.data
# Out:
#                               price   returns     SMA_S     SMA_L
# time
# 2019-01-01 22:00:00+00:00  1.146320       NaN       NaN       NaN
# 2019-01-01 22:20:00+00:00  1.146455  0.000118       NaN       NaN
# 2019-01-01 22:40:00+00:00  1.146410 -0.000039       NaN       NaN
# 2019-01-01 23:00:00+00:00  1.146670  0.000227       NaN       NaN
# 2019-01-01 23:20:00+00:00  1.146630 -0.000035       NaN       NaN
# ...                             ...       ...       ...       ...
# 2020-08-30 22:20:00+00:00  1.190970  0.000382  1.189587  1.185039
# 2020-08-30 22:40:00+00:00  1.190860 -0.000092  1.189669  1.185091
# 2020-08-30 23:00:00+00:00  1.190690 -0.000143  1.189746  1.185141
# 2020-08-30 23:20:00+00:00  1.190895  0.000172  1.189829  1.185192
# 2020-08-30 23:40:00+00:00  1.191715  0.000688  1.189886  1.185250
#
# [31017 rows x 4 columns]

# %%
tester.test_strategy()
# Out:
# (1.167425, 0.121157)

# %%
tester.plot_results()

# %%
tester.results
# Out:
#                               price   returns     SMA_S     SMA_L  position  \
# time
# 2019-01-04 00:00:00+00:00  1.139460  0.000391  1.138221  1.139135        -1
# 2019-01-04 00:20:00+00:00  1.139845  0.000338  1.138279  1.139091        -1
# 2019-01-04 00:40:00+00:00  1.140560  0.000627  1.138358  1.139052        -1
# 2019-01-04 01:00:00+00:00  1.140545 -0.000013  1.138418  1.139011        -1
# 2019-01-04 01:20:00+00:00  1.140750  0.000180  1.138473  1.138972        -1
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 22:20:00+00:00  1.190970  0.000382  1.189587  1.185039         1
# 2020-08-30 22:40:00+00:00  1.190860 -0.000092  1.189669  1.185091         1
# 2020-08-30 23:00:00+00:00  1.190690 -0.000143  1.189746  1.185141         1
# 2020-08-30 23:20:00+00:00  1.190895  0.000172  1.189829  1.185192         1
# 2020-08-30 23:40:00+00:00  1.191715  0.000688  1.189886  1.185250         1
#
#                            strategy  trades  creturns  cstrategy
# time
# 2019-01-04 00:00:00+00:00 -0.000391     0.0  1.000391   0.999609
# 2019-01-04 00:20:00+00:00 -0.000338     0.0  1.000729   0.999272
# 2019-01-04 00:40:00+00:00 -0.000627     0.0  1.001356   0.998645
# 2019-01-04 01:00:00+00:00  0.000013     0.0  1.001343   0.998659
# 2019-01-04 01:20:00+00:00 -0.000180     0.0  1.001523   0.998479
# ...                             ...     ...       ...        ...
# 2020-08-30 22:20:00+00:00  0.000382     0.0  1.045614   1.166695
# 2020-08-30 22:40:00+00:00 -0.000092     0.0  1.045517   1.166587
# 2020-08-30 23:00:00+00:00 -0.000143     0.0  1.045368   1.166421
# 2020-08-30 23:20:00+00:00  0.000172     0.0  1.045548   1.166622
# 2020-08-30 23:40:00+00:00  0.000688     0.0  1.046268   1.167425
#
# [30867 rows x 9 columns]

# %%
tester.results[["SMA_S", "SMA_L", "position"]].plot(secondary_y = "position", figsize = (12, 8))
plt.show()

# %%
tester.results.trades.value_counts()
# Out:
# trades
# 0.0    30650
# 2.0      217
# Name: count, dtype: int64

# %% [markdown]
# ## Mean Reversion Strategy

# %%
import MeanRevBacktester as MeanRev

# %%
start = "2019-01-01"
end = "2020-08-30"
symbol = "EURUSD"
sma = 75
dev = 3
tc = 0.00007

# %%
tester2 = MeanRev.MeanRevBacktester(symbol, sma, dev, start, end, tc)

# %%
tester2
# Out:
# MeanRevBacktester(symbol = EURUSD, SMA = 75, dev = 3, start = 2019-01-01, end = 2020-08-30)

# %%
tester2.data
# Out:
#                               price   returns       SMA     Lower     Upper
# time
# 2019-01-01 22:00:00+00:00  1.146320       NaN       NaN       NaN       NaN
# 2019-01-01 22:20:00+00:00  1.146455  0.000118       NaN       NaN       NaN
# 2019-01-01 22:40:00+00:00  1.146410 -0.000039       NaN       NaN       NaN
# 2019-01-01 23:00:00+00:00  1.146670  0.000227       NaN       NaN       NaN
# 2019-01-01 23:20:00+00:00  1.146630 -0.000035       NaN       NaN       NaN
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 22:20:00+00:00  1.190970  0.000382  1.187613  1.178012  1.197214
# 2020-08-30 22:40:00+00:00  1.190860 -0.000092  1.187729  1.178260  1.197199
# 2020-08-30 23:00:00+00:00  1.190690 -0.000143  1.187841  1.178514  1.197169
# 2020-08-30 23:20:00+00:00  1.190895  0.000172  1.187957  1.178783  1.197131
# 2020-08-30 23:40:00+00:00  1.191715  0.000688  1.188089  1.179077  1.197100
#
# [31017 rows x 5 columns]

# %%
tester2.test_strategy()
# Out:
# (1.013488, -0.038307)

# %%
tester2.plot_results()

# %%
tester2.results
# Out:
#                               price   returns       SMA     Lower     Upper  \
# time
# 2019-01-02 23:00:00+00:00  1.133395  0.000322  1.140925  1.124549  1.157301
# 2019-01-02 23:20:00+00:00  1.133210 -0.000163  1.140748  1.124273  1.157223
# 2019-01-02 23:40:00+00:00  1.131250 -0.001731  1.140546  1.123869  1.157223
# 2019-01-03 00:00:00+00:00  1.133775  0.002230  1.140374  1.123675  1.157074
# 2019-01-03 00:20:00+00:00  1.133955  0.000159  1.140205  1.123506  1.156905
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 22:20:00+00:00  1.190970  0.000382  1.187613  1.178012  1.197214
# 2020-08-30 22:40:00+00:00  1.190860 -0.000092  1.187729  1.178260  1.197199
# 2020-08-30 23:00:00+00:00  1.190690 -0.000143  1.187841  1.178514  1.197169
# 2020-08-30 23:20:00+00:00  1.190895  0.000172  1.187957  1.178783  1.197131
# 2020-08-30 23:40:00+00:00  1.191715  0.000688  1.188089  1.179077  1.197100
#
#                            distance  position  strategy  trades  creturns  \
# time
# 2019-01-02 23:00:00+00:00 -0.007530       0.0       0.0     0.0  1.000322
# 2019-01-02 23:20:00+00:00 -0.007538       0.0      -0.0     0.0  1.000159
# 2019-01-02 23:40:00+00:00 -0.009296       0.0      -0.0     0.0  0.998429
# 2019-01-03 00:00:00+00:00 -0.006599       0.0       0.0     0.0  1.000658
# 2019-01-03 00:20:00+00:00 -0.006250       0.0       0.0     0.0  1.000816
# ...                             ...       ...       ...     ...       ...
# 2020-08-30 22:20:00+00:00  0.003357       0.0       0.0     0.0  1.051137
# 2020-08-30 22:40:00+00:00  0.003131       0.0      -0.0     0.0  1.051040
# 2020-08-30 23:00:00+00:00  0.002849       0.0      -0.0     0.0  1.050890
# 2020-08-30 23:20:00+00:00  0.002938       0.0       0.0     0.0  1.051071
# 2020-08-30 23:40:00+00:00  0.003626       0.0       0.0     0.0  1.051795
#
#                            cstrategy
# time
# 2019-01-02 23:00:00+00:00   1.000000
# 2019-01-02 23:20:00+00:00   1.000000
# 2019-01-02 23:40:00+00:00   1.000000
# 2019-01-03 00:00:00+00:00   1.000000
# 2019-01-03 00:20:00+00:00   1.000000
# ...                              ...
# 2020-08-30 22:20:00+00:00   1.013488
# 2020-08-30 22:40:00+00:00   1.013488
# 2020-08-30 23:00:00+00:00   1.013488
# 2020-08-30 23:20:00+00:00   1.013488
# 2020-08-30 23:40:00+00:00   1.013488
#
# [30942 rows x 11 columns]

# %%
tester2.results.position.plot(figsize = (12, 8))
plt.show()

# %%
tester2.results.trades.value_counts()
# Out:
# trades
# 0.0    30520
# 1.0      422
# Name: count, dtype: int64

# %% [markdown]
# ## Combining both Strategies

# %% [markdown]
# __Goal:__ Stronger Signals / Identify Weak Signals

# %% [markdown]
# __Two different Methods:__

# %% [markdown]
# __Unanimous Signals__ (pro: strong signals | con: restrictive / doesn´t work with too many Indicators)
# - Go Long if all Signals are long
# - Go Short if all Signals are short
# - Go Neutral if Signals are nonunanimous

# %% [markdown]
# __Majority / Tendency__ (pro: can be customized | con: more trades / weaker signals)
# - Go Long if at least two Signals are long (3 Signals Case)
# - Go Long if > [50%] of Signals are long and < [25%] of Signals are short (many Signals Case)

# %%
tester.results
# Out:
#                               price   returns     SMA_S     SMA_L  position  \
# time
# 2019-01-04 00:00:00+00:00  1.139460  0.000391  1.138221  1.139135        -1
# 2019-01-04 00:20:00+00:00  1.139845  0.000338  1.138279  1.139091        -1
# 2019-01-04 00:40:00+00:00  1.140560  0.000627  1.138358  1.139052        -1
# 2019-01-04 01:00:00+00:00  1.140545 -0.000013  1.138418  1.139011        -1
# 2019-01-04 01:20:00+00:00  1.140750  0.000180  1.138473  1.138972        -1
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 22:20:00+00:00  1.190970
# 2020-08-30 22:40:00+00:00  0.003131       0.0      -0.0     0.0  1.051040
# 2020-08-30 23:00:00+00:00  0.002849       0.0      -0.0     0.0  1.050890
# 2020-08-30 23:20:00+00:00  0.002938       0.0       0.0     0.0  1.051071
# 2020-08-30 23:40:00+00:00  0.003626       0.0       0.0     0.0  1.051795
#
#                            cstrategy
# time
# 2019-01-02 23:00:00+00:00   1.000000
# 2019-01-02 23:20:00+00:00   1.000000
# 2019-01-02 23:40:00+00:00   1.000000
# 2019-01-03 00:00:00+00:00   1.000000
# 2019-01-03 00:20:00+00:00   1.000000
# ...                              ...
# 2020-08-30 22:20:00+00:00   1.013488
# 2020-08-30 22:40:00+00:00   1.013488
# 2020-08-30 23:00:00+00:00   1.013488
# 2020-08-30 23:20:00+00:00   1.013488
# 2020-08-30 23:40:00+00:00   1.013488
#
# [30942 rows x 11 columns]

# %%
comb = tester.results.loc[:, ["returns", "position"]].copy()

# %%
comb
# Out:
#                             returns  position
# time
# 2019-01-04 00:00:00+00:00  0.000391        -1
# 2019-01-04 00:20:00+00:00  0.000338        -1
# 2019-01-04 00:40:00+00:00  0.000627        -1
# 2019-01-04 01:00:00+00:00 -0.000013        -1
# 2019-01-04 01:20:00+00:00  0.000180        -1
# ...                             ...       ...
# 2020-08-30 22:20:00+00:00  0.000382         1
# 2020-08-30 22:40:00+00:00 -0.000092         1
# 2020-08-30 23:00:00+00:00 -0.000143         1
# 2020-08-30 23:20:00+00:00  0.000172         1
# 2020-08-30 23:40:00+00:00  0.000688         1
#
# [30867 rows x 2 columns]

# %%
comb.rename(columns = {"position":"position_SMA"}, inplace = True)

# %%
comb["position_MR"] = tester2.results.position.astype("int")

# %%
comb
# Out:
#                             returns  position_SMA  position_MR
# time
# 2019-01-04 00:00:00+00:00  0.000391            -1           -1
# 2019-01-04 00:20:00+00:00  0.000338            -1           -1
# 2019-01-04 00:40:00+00:00  0.000627            -1           -1
# 2019-01-04 01:00:00+00:00 -0.000013            -1           -1
# 2019-01-04 01:20:00+00:00  0.000180            -1           -1
# ...                             ...           ...          ...
# 2020-08-30 22:20:00+00:00  0.000382             1            0
# 2020-08-30 22:40:00+00:00 -0.000092             1            0
# 2020-08-30 23:00:00+00:00 -0.000143             1            0
# 2020-08-30 23:20:00+00:00  0.000172             1            0
# 2020-08-30 23:40:00+00:00  0.000688             1            0
#
# [30867 rows x 3 columns]

# %% [markdown]
# __Alternative 1: Unanimous Signals__

# %%
#comb["position_comb"] = np.where(comb.position_MR == comb.position_SMA, comb.position_MR, 0)

# %% [markdown]
# __Alternative 2: Majority / Tendency__

# %%
comb["position_comb"] = np.sign(comb.position_MR + comb.position_SMA)

# %%
comb.head(60)
# Out:
#                             returns  position_SMA  position_MR  position_comb
# time
# 2019-01-04 00:00:00+00:00  0.000391            -1           -1             -1
# 2019-01-04 00:20:00+00:00  0.000338            -1           -1             -1
# 2019-01-04 00:40:00+00:00  0.000627            -1           -1             -1
# 2019-01-04 01:00:00+00:00 -0.000013            -1           -1             -1
# 2019-01-04 01:20:00+00:00  0.000180            -1           -1             -1
# 2019-01-04 18:20:00+00:00 -0.000101             1            0              1
# 2019-01-04 18:40:00+00:00 -0.000311             1            0              1
# 2019-01-04 19:00:00+00:00 -0.000360             1            0              1
# 2019-01-04 19:20:00+00:00  0.000123             1            0              1
# 2019-01-04 19:40:00+00:00 -0.000132             1            0              1

# %%
comb.position_comb.value_counts()
# Out:
# position_comb
#  0    10636
# -1    10215
#  1    10016
# Name: count, dtype: int64

# %%
comb.position_comb.plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# ## Taking into account busy trading hours

# %%
comb
# Out:
#                             returns  position_SMA  position_MR  position_comb
# time
# 2019-01-04 00:00:00+00:00  0.000391            -1           -1             -1
# 2019-01-04 00:20:00+00:00  0.000338            -1           -1             -1
# 2019-01-04 00:40:00+00:00  0.000627            -1           -1             -1
# 2019-01-04 01:00:00+00:00 -0.000013            -1           -1             -1
# 2019-01-04 01:20:00+00:00  0.000180            -1           -1             -1
# ...                             ...           ...          ...            ...
# 2020-08-30 22:20:00+00:00  0.000382             1            0              1
# 2020-08-30 22:40:00+00:00 -0.000092             1            0              1
# 2020-08-30 23:00:00+00:00 -0.000143             1            0              1
# 2020-08-30 23:20:00+00:00  0.000172             1            0              1
# 2020-08-30 23:40:00+00:00  0.000688             1            0              1
#
# [30867 rows x 4 columns]

# %%
comb["NYTime"] = comb.index.tz_convert("America/New_York")
comb["hour"] = comb.NYTime.dt.hour

# %%
comb.position_comb = np.where(comb.hour.between(2, 12), comb.position_comb, 0)

# %%
comb.position_comb.value_counts()
# Out:
# position_comb
#  0    20862
#  1     5029
# -1     4976
# Name: count, dtype: int64

# %%
comb.position_comb.plot(figsize = (12, 8))
plt.show()

# %%
comb.position_comb.loc["2020-08"].plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# ## Backtesting

# %%
comb
# Out:
#                             returns  position_SMA  position_MR  position_comb  \
# time
# 2019-01-04 00:00:00+00:00  0.000391            -1           -1              0
# 2019-01-04 00:20:00+00:00  0.000338            -1           -1              0
# 2019-01-04 00:40:00+00:00  0.000627            -1           -1              0
# 2019-01-04 01:00:00+00:00 -0.000013            -1           -1              0
# 2019-01-04 01:20:00+00:00  0.000180            -1           -1              0
# ...                             ...           ...          ...            ...
# 2020-08-30 22:20:00+00:00  0.000382             1            0              0
# 2020-08-30 22:40:00+00:00 -0.000092             1            0              0
# 2020-08-30 23:00:00+00:00 -0.000143             1            0              0
# 2020-08-30 23:20:00+00:00  0.000172             1            0              0
# 2020-08-30 23:40:00+00:00  0.000688             1            0              0
#
#                                              NYTime  hour
# time
# 2019-01-04 00:00:00+00:00 2019-01-03 19:00:00-05:00    19
# 2019-01-04 00:20:00+00:00 2019-01-03 19:20:00-05:00    19
# 2019-01-04 00:40:00+00:00 2019-01-03 19:40:00-05:00    19
# 2019-01-04 01:00:00+00:00 2019-01-03 20:00:00-05:00    20
# 2019-01-04 01:20:00+00:00 2019-01-03 20:20:00-05:00    20
# ...                                             ...   ...
# 2020-08-30 22:20:00+00:00 2020-08-30 18:20:00-04:00    18
# 2020-08-30 22:40:00+00:00 2020-08-30 18:40:00-04:00    18
# 2020-08-30 23:00:00+00:00 2020-08-30 19:00:00-04:00    19
# 2020-08-30 23:20:00+00:00 2020-08-30 19:20:00-04:00    19
# 2020-08-30 23:40:00+00:00 2020-08-30 19:40:00-04:00    19
#
# [30867 rows x 6 columns]

# %%
comb["strategy"] = comb["position_comb"].shift(1) * comb["returns"]

# %%
comb.dropna(inplace=True)

# %%
comb["trades"] = comb.position_comb.diff().fillna(0).abs()

# %%
tc = 0.000059

# %%
comb.strategy = comb.strategy - comb.trades * tc

# %%
comb["creturns"] = comb["returns"].cumsum().apply(np.exp)
comb["cstrategy"] = comb["strategy"].cumsum().apply(np.exp)

# %%
comb[["creturns", "cstrategy"]].plot(figsize = (12, 8), title = "EUR/USD - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12)
plt.legend(fontsize = 12)
plt.show()

# %%
comb.trades.value_counts()
# Out:
# trades
# 0.0    29980
# 1.0      830
# 2.0       56
# Name: count, dtype: int64

# %% [markdown]
# ## Strategy Optimization

# %%
import SMABacktester as SMA
import MeanRevBacktester as MeanRev

# %%
def optimal_strategy(parameters):
    
    start = "2019-01-01"
    end = "2020-08-30"
    symbol = "EURUSD"
    tc = 0.000059
    
    # SMA
    tester1 = SMA.SMABacktester(symbol, int(parameters[0]), int(parameters[1]), start, end, tc)
    tester1.test_strategy()
    
    # Bollinger
    tester2 = MeanRev.MeanRevBacktester(symbol,  int(parameters[2]),  int(parameters[3]), start, end, tc)
    tester2.test_strategy()
    
    # Create comb
    comb = tester1.results.loc[:, ["returns", "position"]].copy()
    comb.rename(columns = {"position":"position_SMA"}, inplace = True)
    comb["position_MR"] = tester2.results.position
    
    # 2 Methods
    #comb["position_comb"] = np.where(comb.position_MR == comb.position_SMA, comb.position_MR, 0) 
    comb["position_comb"] = np.sign(comb.position_MR + comb.position_SMA)
    
    # Busy Hours
    comb["NYTime"] = comb.index.tz_convert("America/New_York")
    comb["hour"] = comb.NYTime.dt.hour
    comb.position_comb = np.where(comb.hour.between(2, 12), comb.position_comb, 0)
    
    # Backtest
    comb["strategy"] = comb["position_comb"].shift(1) * comb["returns"]
    comb.dropna(inplace=True)
    comb["trades"] = comb.position_comb.diff().fillna(0).abs()
    comb.strategy = comb.strategy - comb.trades * tc
    comb["creturns"] = comb["returns"].cumsum().apply(np.exp)
    comb["cstrategy"] = comb["strategy"].cumsum().apply(np.exp)
    
    return -comb["cstrategy"].iloc[-1] # negative absolute performance to be minimized

# %%
optimal_strategy((50, 150, 75, 3))
# Out:
# -1.150153534460439

# %%
from scipy.optimize import minimize

# %%
bnds =  ((25, 75), (100, 200), (50, 100), (1, 5))
bnds
# Out:
# ((25, 75), (100, 200), (50, 100), (1, 5))

# %%
start_par = (50, 150, 75, 3)

# %%
#run optimization based on function to be minimized, starting with start parameters
opts = minimize(optimal_strategy, start_par, method = "Powell" , bounds = bnds)

# %%
opts
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: -1.2368971057690088
#        x: [ 5.208e+01  1.813e+02  5.921e+01  3.454e+00]
#      nit: 4
#    direc: [[ 0.000e+00  0.000e+00  0.000e+00  1.000e+00]
#            [ 0.000e+00  1.000e+00  0.000e+00  0.000e+00]
#            [ 0.000e+00  0.000e+00  1.000e+00  0.000e+00]
#            [ 1.214e+01  1.707e+00  1.361e-05  1.086e-02]]
#     nfev: 380

# %%
optimal_strategy(opts.x)
# Out:
# -1.2368971057690088
