# %% [markdown]
# # Creating and Backtesting simple Momentum/Contrarian Strategies

# %% [markdown]
# ## Getting the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
data = pd.read_csv("intraday.csv", parse_dates = ["time"], index_col = "time")

# %%
data
# Out:
#                               price
# time
# 2018-01-01 22:00:00+00:00  1.201205
# 2018-01-02 04:00:00+00:00  1.207055
# 2018-01-02 10:00:00+00:00  1.204440
# 2018-01-02 16:00:00+00:00  1.205800
# 2018-01-02 22:00:00+00:00  1.204690
# ...                             ...
# 2019-12-29 22:00:00+00:00  1.119920
# 2019-12-30 04:00:00+00:00  1.119940
# 2019-12-30 10:00:00+00:00  1.120095
# 2019-12-30 16:00:00+00:00  1.119920
# 2019-12-30 22:00:00+00:00  1.120355
#
# [2070 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2070 entries, 2018-01-01 22:00:00+00:00 to 2019-12-30 22:00:00+00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   2070 non-null   float64
# dtypes: float64(1)
# memory usage: 32.3 KB

# %%
data.plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.show()

# %%
data.loc["2019-06"].plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.show()

# %%
data["returns"] = np.log(data.div(data.shift(1)))

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                               price   returns
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169
# 2018-01-02 16:00:00+00:00  1.205800  0.001129
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718
# ...                             ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388
#
# [2069 rows x 2 columns]

# %% [markdown]
# ## Defining a simple Contrarian Strategy (window = 3)

# %%
window = 3

# %%
data
# Out:
#                               price   returns
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169
# 2018-01-02 16:00:00+00:00  1.205800  0.001129
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718
# ...                             ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388
#
# [2069 rows x 2 columns]

# %%
data["returns"].rolling(window).mean()
# Out:
# time
# 2018-01-02 04:00:00+00:00             NaN
# 2018-01-02 10:00:00+00:00             NaN
# 2018-01-02 16:00:00+00:00    1.272676e-03
# 2018-01-02 22:00:00+00:00   -6.537454e-04
# 2018-01-03 04:00:00+00:00   -1.702470e-04
#                                  ...
# 2019-12-29 22:00:00+00:00    1.808598e-03
# 2019-12-30 04:00:00+00:00    1.085156e-03
# 2019-12-30 10:00:00+00:00    7.492899e-04
# 2019-12-30 16:00:00+00:00   -1.542278e-17
# 2019-12-30 22:00:00+00:00    1.234956e-04
# Name: returns, Length: 2069, dtype: float64

# %%
data["position"] = -np.sign(data["returns"].rolling(window).mean()) # contrarian (minus sign)

# %%
data
# Out:
#                               price   returns  position
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858       NaN
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169       NaN
# 2018-01-02 16:00:00+00:00  1.205800  0.001129      -1.0
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718       1.0
# ...                             ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0
#
# [2069 rows x 3 columns]

# %% [markdown]
# ## Vectorized Strategy Backtesting

# %%
data["strategy"] = data.position.shift(1) * data["returns"]

# %%
data
# Out:
#                               price   returns  position  strategy
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858       NaN       NaN
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169       NaN       NaN
# 2018-01-02 16:00:00+00:00  1.205800  0.001129      -1.0       NaN
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0  0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718       1.0 -0.000718
# ...                             ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0 -0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0 -0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0 -0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0  0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0  0.000388
#
# [2069 rows x 4 columns]

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                               price   returns  position  strategy
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0  0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718       1.0 -0.000718
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222       1.0 -0.001222
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757       1.0 -0.000757
# 2018-01-03 22:00:00+00:00  1.201450  0.000004       1.0  0.000004
# ...                             ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0 -0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0 -0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0 -0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0  0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0  0.000388
#
# [2066 rows x 4 columns]

# %%
data[["returns", "strategy"]].sum()
# Out:
# returns    -0.073498
# strategy    0.096236
# dtype: float64

# %%
data[["returns", "strategy"]].sum().apply(np.exp)
# Out:
# returns     0.929138
# strategy    1.101019
# dtype: float64

# %%
data["creturns"] = data["returns"].cumsum().apply(np.exp)
data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)

# %%
data
# Out:
#                               price   returns  position  strategy  creturns  \
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0  0.000921  0.999079
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718       1.0 -0.000718  0.998362
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222       1.0 -0.001222  0.997143
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757       1.0 -0.000757  0.996388
# 2018-01-03 22:00:00+00:00  1.201450  0.000004       1.0  0.000004  0.996392
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0 -0.002092  0.928778
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0 -0.000018  0.928794
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0 -0.000138  0.928923
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0  0.000156  0.928778
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0  0.000388  0.929138
#
#                            cstrategy
# time
# 2018-01-02 22:00:00+00:00   1.000921
# 2018-01-03 04:00:00+00:00   1.000203
# 2018-01-03 10:00:00+00:00   0.998981
# 2018-01-03 16:00:00+00:00   0.998225
# 2018-01-03 22:00:00+00:00   0.998229
# ...                              ...
# 2019-12-29 22:00:00+00:00   1.100591
# 2019-12-30 04:00:00+00:00   1.100572
# 2019-12-30 10:00:00+00:00   1.100420
# 2019-12-30 16:00:00+00:00   1.100591
# 2019-12-30 22:00:00+00:00   1.101019
#
# [2066 rows x 6 columns]

# %%
data[["creturns", "cstrategy"]].plot(figsize = (12 , 8),
                                     title = "EUR/USD | Window = {}".format(window), fontsize = 12)
plt.show()

# %% [markdown]
# ## Changing the window parameter

# %%
data = pd.read_csv("intraday.csv", parse_dates = ["time"], index_col = "time")

# %%
data
# Out:
#                               price
# time
# 2018-01-01 22:00:00+00:00  1.201205
# 2018-01-02 04:00:00+00:00  1.207055
# 2018-01-02 10:00:00+00:00  1.204440
# 2018-01-02 16:00:00+00:00  1.205800
# 2018-01-02 22:00:00+00:00  1.204690
# ...                             ...
# 2019-12-29 22:00:00+00:00  1.119920
# 2019-12-30 04:00:00+00:00  1.119940
# 2019-12-30 10:00:00+00:00  1.120095
# 2019-12-30 16:00:00+00:00  1.119920
# 2019-12-30 22:00:00+00:00  1.120355
#
# [2070 rows x 1 columns]

# %%
data["returns"] = np.log(data.div(data.shift(1)))

# %%
data.dropna(inplace = True)
data
# Out:
#                               price   returns
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169
# 2018-01-02 16:00:00+00:00  1.205800  0.001129
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718
# ...                             ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388
#
# [2069 rows x 2 columns]

# %%
to_plot = ["returns"]

# %%
for w in [1, 2, 3, 5, 10]:
    data["position{}".format(w)] = -np.sign(data["returns"].rolling(w).mean())
    data["strategy{}".format(w)] = data["position{}".format(w)].shift(1) * data["returns"]
    to_plot.append("strategy{}".format(w))

# %%
data
# Out:
#                               price   returns  position1  strategy1  \
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858       -1.0        NaN
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169        1.0   0.002169
# 2018-01-02 16:00:00+00:00  1.205800  0.001129       -1.0   0.001129
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921        1.0   0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718        1.0  -0.000718
# ...                             ...       ...        ...        ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092       -1.0  -0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018       -1.0  -0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138       -1.0  -0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156        1.0   0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388       -1.0   0.000388
#
#                            position2  strategy2  position3  strategy3  \
# time
# 2018-01-02 04:00:00+00:00        NaN        NaN        NaN        NaN
# 2018-01-02 10:00:00+00:00       -1.0        NaN        NaN        NaN
# 2018-01-02 16:00:00+00:00        1.0  -0.001129       -1.0        NaN
# 2018-01-02 22:00:00+00:00       -1.0  -0.000921        1.0   0.000921
# 2018-01-03 04:00:00+00:00        1.0   0.000718        1.0  -0.000718
# ...                              ...        ...        ...        ...
# 2019-12-29 22:00:00+00:00       -1.0  -0.002092       -1.0  -0.002092
# 2019-12-30 04:00:00+00:00       -1.0  -0.000018       -1.0  -0.000018
# 2019-12-30 10:00:00+00:00       -1.0  -0.000138       -1.0  -0.000138
# 2019-12-30 16:00:00+00:00        1.0   0.000156        1.0   0.000156
# 2019-12-30 22:00:00+00:00       -1.0   0.000388       -1.0   0.000388
#
#                            position5  strategy5  position10  strategy10
# time
# 2018-01-02 04:00:00+00:00        NaN        NaN         NaN         NaN
# 2018-01-02 10:00:00+00:00        NaN        NaN         NaN         NaN
# 2018-01-02 16:00:00+00:00        NaN        NaN         NaN         NaN
# 2018-01-02 22:00:00+00:00        NaN        NaN         NaN         NaN
# 2018-01-03 04:00:00+00:00       -1.0        NaN         NaN         NaN
# ...                              ...        ...         ...         ...
# 2019-12-29 22:00:00+00:00       -1.0  -0.002092        -1.0   -0.002092
# 2019-12-30 04:00:00+00:00       -1.0  -0.000018        -1.0   -0.000018
# 2019-12-30 10:00:00+00:00       -1.0  -0.000138        -1.0   -0.000138
# 2019-12-30 16:00:00+00:00       -1.0   0.000156        -1.0    0.000156
# 2019-12-30 22:00:00+00:00       -1.0  -0.000388        -1.0   -0.000388
#
# [2069 rows x 12 columns]

# %%
to_plot
# Out:
# ['returns', 'strategy1', 'strategy2', 'strategy3', 'strategy5', 'strategy10']

# %%
data[to_plot].dropna().cumsum().apply(np.exp).plot(figsize = (12, 8))
plt.title("DJI Intraday - 6h bars", fontsize = 12)
plt.legend(fontsize = 12)
plt.show()

# %%
data
# Out:
#                               price   returns  position1  strategy1  \
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858       -1.0        NaN
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169        1.0   0.002169
# 2018-01-02 16:00:00+00:00  1.205800  0.001129       -1.0   0.001129
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921        1.0   0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718        1.0  -0.000718
# ...                             ...       ...        ...        ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092       -1.0  -0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018       -1.0  -0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138       -1.0  -0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156        1.0   0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388       -1.0   0.000388
#
#                            position2  strategy2  position3  strategy3  \
# time
# 2018-01-02 04:00:00+00:00        NaN        NaN        NaN        NaN
# 2018-01-02 10:00:00+00:00       -1.0        NaN        NaN        NaN
# 2018-01-02 16:00:00+00:00        1.0  -0.001129       -1.0        NaN
# 2018-01-02 22:00:00+00:00       -1.0  -0.000921        1.0   0.000921
# 2018-01-03 04:00:00+00:00        1.0   0.000718        1.0  -0.000718
# ...                              ...        ...        ...        ...
# 2019-12-29 22:00:00+00:00       -1.0  -0.002092       -1.0  -0.002092
# 2019-12-30 04:00:00+00:00       -1.0  -0.000018       -1.0  -0.000018
# 2019-12-30 10:00:00+00:00       -1.0  -0.000138       -1.0  -0.000138
# 2019-12-30 16:00:00+00:00        1.0   0.000156        1.0   0.000156
# 2019-12-30 22:00:00+00:00       -1.0   0.000388       -1.0   0.000388
#
#                            position5  strategy5  position10  strategy10
# time
# 2018-01-02 04:00:00+00:00        NaN        NaN         NaN         NaN
# 2018-01-02 10:00:00+00:00        NaN        NaN         NaN         NaN
# 2018-01-02 16:00:00+00:00        NaN        NaN         NaN         NaN
# 2018-01-02 22:00:00+00:00        NaN        NaN         NaN         NaN
# 2018-01-03 04:00:00+00:00       -1.0        NaN         NaN         NaN
# ...                              ...        ...         ...         ...
# 2019-12-29 22:00:00+00:00       -1.0  -0.002092        -1.0   -0.002092
# 2019-12-30 04:00:00+00:00       -1.0  -0.000018        -1.0   -0.000018
# 2019-12-30 10:00:00+00:00       -1.0  -0.000138        -1.0   -0.000138
# 2019-12-30 16:00:00+00:00       -1.0   0.000156        -1.0    0.000156
# 2019-12-30 22:00:00+00:00       -1.0  -0.000388        -1.0   -0.000388
#
# [2069 rows x 12 columns]

# %% [markdown]
# ## Trades and Trading Costs (Part 1)

# %%
data = pd.read_csv("intraday.csv", parse_dates = ["time"], index_col = "time")

# %%
window = 3

# %%
data["returns"] = np.log(data.div(data.shift(1)))

# %%
data["position"] = -np.sign(data["returns"].rolling(window).mean())

# %%
data["strategy"] = data.position.shift(1) * data["returns"]

# %%
data
# Out:
#                               price   returns  position  strategy
# time
# 2018-01-01 22:00:00+00:00  1.201205       NaN       NaN       NaN
# 2018-01-02 04:00:00+00:00  1.207055  0.004858       NaN       NaN
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169       NaN       NaN
# 2018-01-02 16:00:00+00:00  1.205800  0.001129      -1.0       NaN
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0  0.000921
# ...                             ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0 -0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0 -0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0 -0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0  0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0  0.000388
#
# [2070 rows x 4 columns]

# %%
data.dropna(inplace = True)

# %%
data["creturns"] = data["returns"].cumsum().apply(np.exp)
data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)

# %%
data
# Out:
#                               price   returns  position  strategy  creturns  \
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0  0.000921  0.999079
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718       1.0 -0.000718  0.998362
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222       1.0 -0.001222  0.997143
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757       1.0 -0.000757  0.996388
# 2018-01-03 22:00:00+00:00  1.201450  0.000004       1.0  0.000004  0.996392
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0 -0.002092  0.928778
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0 -0.000018  0.928794
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0 -0.000138  0.928923
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0  0.000156  0.928778
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0  0.000388  0.929138
#
#                            cstrategy
# time
# 2018-01-02 22:00:00+00:00   1.000921
# 2018-01-03 04:00:00+00:00   1.000203
# 2018-01-03 10:00:00+00:00   0.998981
# 2018-01-03 16:00:00+00:00   0.998225
# 2018-01-03 22:00:00+00:00   0.998229
# ...                              ...
# 2019-12-29 22:00:00+00:00   1.100591
# 2019-12-30 04:00:00+00:00   1.100572
# 2019-12-30 10:00:00+00:00   1.100420
# 2019-12-30 16:00:00+00:00   1.100591
# 2019-12-30 22:00:00+00:00   1.101019
#
# [2066 rows x 6 columns]

# %%
data.loc[:, "position"].plot(figsize = (12 , 8))
plt.show()

# %%
data.loc["2019-06", "position"].plot(figsize = (12 , 8))
plt.show()

# %% [markdown]
# __Trading/Transaction Costs__ (simplified)

# %%
spread = 1.5 * 0.0001 # pips == fourth price decimal
spread
# Out:
# 0.00015000000000000001

# %%
half_spread = spread / 2 # absolute tc per trade (position change +-1)
half_spread
# Out:
# 7.500000000000001e-05

# %%
ptc = half_spread / data.price.mean() # proportional tc per trade (position change +-1)
ptc
# Out:
# 6.520065892008921e-05

# %%
ptc = 0.00007

# %%
data
# Out:
#                               price   returns  position  strategy  creturns  \
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0  0.000921  0.999079
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718       1.0 -0.000718  0.998362
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222       1.0 -0.001222  0.997143
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757       1.0 -0.000757  0.996388
# 2018-01-03 22:00:00+00:00  1.201450  0.000004       1.0  0.000004  0.996392
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0 -0.002092  0.928778
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0 -0.000018  0.928794
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0 -0.000138  0.928923
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0  0.000156  0.928778
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0  0.000388  0.929138
#
#                            cstrategy
# time
# 2018-01-02 22:00:00+00:00   1.000921
# 2018-01-03 04:00:00+00:00   1.000203
# 2018-01-03 10:00:00+00:00   0.998981
# 2018-01-03 16:00:00+00:00   0.998225
# 2018-01-03 22:00:00+00:00   0.998229
# ...                              ...
# 2019-12-29 22:00:00+00:00   1.100591
# 2019-12-30 04:00:00+00:00   1.100572
# 2019-12-30 10:00:00+00:00   1.100420
# 2019-12-30 16:00:00+00:00   1.100591
# 2019-12-30 22:00:00+00:00   1.101019
#
# [2066 rows x 6 columns]

# %%
data.position.diff().fillna(0).abs()
# Out:
# time
# 2018-01-02 22:00:00+00:00    0.0
# 2018-01-03 04:00:00+00:00    0.0
# 2018-01-03 10:00:00+00:00    0.0
# 2018-01-03 16:00:00+00:00    0.0
# 2018-01-03 22:00:00+00:00    0.0
#                             ...
# 2019-12-29 22:00:00+00:00    0.0
# 2019-12-30 04:00:00+00:00    0.0
# 2019-12-30 10:00:00+00:00    0.0
# 2019-12-30 16:00:00+00:00    2.0
# 2019-12-30 22:00:00+00:00    2.0
# Name: position, Length: 2066, dtype: float64

# %%
data["trades"] = data.position.diff().fillna(0).abs()

# %%
data
# Out:
#                               price   returns  position  strategy  creturns  \
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0  0.000921  0.999079
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718       1.0 -0.000718  0.998362
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222       1.0 -0.001222  0.997143
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757       1.0 -0.000757  0.996388
# 2018-01-03 22:00:00+00:00  1.201450  0.000004       1.0  0.000004  0.996392
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0 -0.002092  0.928778
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0 -0.000018  0.928794
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0 -0.000138  0.928923
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0  0.000156  0.928778
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0  0.000388  0.929138
#
#                            cstrategy  trades
# time
# 2018-01-02 22:00:00+00:00   1.000921     0.0
# 2018-01-03 04:00:00+00:00   1.000203     0.0
# 2018-01-03 10:00:00+00:00   0.998981     0.0
# 2018-01-03 16:00:00+00:00   0.998225     0.0
# 2018-01-03 22:00:00+00:00   0.998229     0.0
# ...                              ...     ...
# 2019-12-29 22:00:00+00:00   1.100591     0.0
# 2019-12-30 04:00:00+00:00   1.100572     0.0
# 2019-12-30 10:00:00+00:00   1.100420     0.0
# 2019-12-30 16:00:00+00:00   1.100591     2.0
# 2019-12-30 22:00:00+00:00   1.101019     2.0
#
# [2066 rows x 7 columns]

# %%
data.trades.value_counts()
# Out:
# trades
# 0.0    1513
# 2.0     553
# Name: count, dtype: int64

# %% [markdown]
# ## Trades and Trading Costs (Part 2)

# %%
data
# Out:
#                               price   returns  position  strategy  creturns  \
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0  0.000921  0.999079
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718       1.0 -0.000718  0.998362
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222       1.0 -0.001222  0.997143
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757       1.0 -0.000757  0.996388
# 2018-01-03 22:00:00+00:00  1.201450  0.000004       1.0  0.000004  0.996392
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0 -0.002092  0.928778
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0 -0.000018  0.928794
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0 -0.000138  0.928923
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0  0.000156  0.928778
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0  0.000388  0.929138
#
#                            cstrategy  trades
# time
# 2018-01-02 22:00:00+00:00   1.000921     0.0
# 2018-01-03 04:00:00+00:00   1.000203     0.0
# 2018-01-03 10:00:00+00:00   0.998981     0.0
# 2018-01-03 16:00:00+00:00   0.998225     0.0
# 2018-01-03 22:00:00+00:00   0.998229     0.0
# ...                              ...     ...
# 2019-12-29 22:00:00+00:00   1.100591     0.0
# 2019-12-30 04:00:00+00:00   1.100572     0.0
# 2019-12-30 10:00:00+00:00   1.100420     0.0
# 2019-12-30 16:00:00+00:00   1.100591     2.0
# 2019-12-30 22:00:00+00:00   1.101019     2.0
#
# [2066 rows x 7 columns]

# %%
data["strategy_net"] = data.strategy - data.trades * ptc

# %%
data["cstrategy_net"] = data.strategy_net.cumsum().apply(np.exp)

# %%
data
# Out:
#                               price   returns  position  strategy  creturns  \
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921       1.0  0.000921  0.999079
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718       1.0 -0.000718  0.998362
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222       1.0 -0.001222  0.997143
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757       1.0 -0.000757  0.996388
# 2018-01-03 22:00:00+00:00  1.201450  0.000004       1.0  0.000004  0.996392
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092      -1.0 -0.002092  0.928778
# 2019-12-30 04:00:00+00:00  1.119940  0.000018      -1.0 -0.000018  0.928794
# 2019-12-30 10:00:00+00:00  1.120095  0.000138      -1.0 -0.000138  0.928923
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156       1.0  0.000156  0.928778
# 2019-12-30 22:00:00+00:00  1.120355  0.000388      -1.0  0.000388  0.929138
#
#                            cstrategy  trades  strategy_net  cstrategy_net
# time
# 2018-01-02 22:00:00+00:00   1.000921     0.0      0.000921       1.000921
# 2018-01-03 04:00:00+00:00   1.000203     0.0     -0.000718       1.000203
# 2018-01-03 10:00:00+00:00   0.998981     0.0     -0.001222       0.998981
# 2018-01-03 16:00:00+00:00   0.998225     0.0     -0.000757       0.998225
# 2018-01-03 22:00:00+00:00   0.998229     0.0      0.000004       0.998229
# ...                              ...     ...           ...            ...
# 2019-12-29 22:00:00+00:00   1.100591     0.0     -0.002092       1.018884
# 2019-12-30 04:00:00+00:00   1.100572     0.0     -0.000018       1.018866
# 2019-12-30 10:00:00+00:00   1.100420     0.0     -0.000138       1.018725
# 2019-12-30 16:00:00+00:00   1.100591     2.0      0.000016       1.018741
# 2019-12-30 22:00:00+00:00   1.101019     2.0      0.000248       1.018994
#
# [2066 rows x 9 columns]

# %%
data[["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12 , 8))
plt.show()
